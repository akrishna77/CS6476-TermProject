# %%
import numpy as np
from sklearn.metrics import roc_curve
from sklearn.neighbors import KNeighborsClassifier
import random
import matplotlib.patheffects as PathEffects

# %%
from keras.layers import Input, Conv2D, Lambda, Dense, Flatten,MaxPooling2D, concatenate
from keras.models import Model, Sequential
from keras.regularizers import l2
from keras import backend as K
from keras.optimizers import SGD,Adam
from keras.losses import binary_crossentropy
import os
import pickle
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip drive-download-20191201T013728Z-001.zip
# Out:
# Archive:  drive-download-20191201T013728Z-001.zip
#   inflating: testOutputPredictions.npy
#   inflating: trainOutputPredictions.npy
#   inflating: testInputImages.npy
#   inflating: triplets_dataset/under_test_triplets.json
#   inflating: triplets_dataset/behind_test_triplets.json
#   inflating: triplets_dataset/next to_test_triplets.json
#   inflating: triplets_dataset/on_test_triplets.json
#   inflating: triplets_dataset/under_train_triplets.json
#   inflating: triplets_dataset/behind_train_triplets.json
#   inflating: triplets_dataset/next to_train_triplets.json
#   inflating: triplets_dataset/on_train_triplets.json
#   inflating: triplets_dataset/_DS_Store
#   inflating: new_json_dataset/objects.json
#   inflating: new_json_dataset/predicates.json
#   inflating: new_json_dataset/annotations_train.json
#   inflating: new_json_dataset/annotations_test.json
#   inflating: balancedInputImages.npy

# %%
from itertools import permutations
import seaborn as sns
from keras.datasets import mnist
from sklearn.manifold import TSNE
from sklearn.svm import SVC
import json

# %%
with open ('/content/triplets_dataset/behind_train_triplets.json') as json_file:
  behind_train=json.load(json_file)

with open ('/content/triplets_dataset/on_train_triplets.json') as json_file:
  on_train=json.load(json_file)


with open ('/content/triplets_dataset/under_train_triplets.json') as json_file:
  under_train=json.load(json_file)


with open ('/content/triplets_dataset/next to_train_triplets.json') as json_file:
  next_to_train=json.load(json_file)

# %%
def create_triplets(behind_train):

  new_dict={}
  for key in behind_train.keys():
    if key=="predicate":
      new_dict[key]=behind_train[key]
      continue
    ex=[]
    val=behind_train[key]
    val=list(val)
    total_length=len(val)
    print(total_length)
    for i in range(int(total_length/2)):
      a_p_n_pairs={}
      a_p_n_pairs["anchor"]=val[i]["filename1"]
      a_p_n_pairs["anchor_details"]=val[i]["positive"]
      a_p_n_pairs["positive"]=val[i+int(total_length/2)]["filename1"]
      a_p_n_pairs["positive_details"]=val[i+int(total_length/2)]["positive"]
      a_p_n_pairs["negative"]=val[i]["filename2"]
      a_p_n_pairs["negative_details"]=val[i]["negative"]
      ex.append(a_p_n_pairs)
      new_dict[key]=ex
  return new_dict

# %%
behind_train_triplets=create_triplets(behind_train)
print(behind_train_triplets)
# Out:
# 1123
# {'predicate': 'behind', 'examples': [{'anchor': '9766932005_d859b2b6da_b.jpg', 'anchor_details': {'bbox1': [458, 606, 232, 601], 'bbox2': [230, 489, 102, 781], 'obj1': 'car', 'obj2': 'bus', 'relationship': 'behind'}, 'positive': '5507320891_fdd19ffbbe_b.jpg', 'positive_details': {'bbox1': [173, 617, 524, 640], 'bbox2': [2, 499, 4, 1023], 'obj1': 'building', 'obj2': 'sky', 'relationship': 'behind'}, 'negative': '5041875929_e3b9620600_b.jpg', 'negative_details': {'bbox1': [498, 552, 363, 467], 'bbox2': [472, 575, 441, 677], 'obj1': 'car', 'obj2': 'bus', 'relationship': 'next to'}}, {'anchor': '4874188_684cc9482e_o.jpg', 'anchor_details': {'bbox1': [106, 476, 1, 922], 'bbox2': [13, 206, 564, 677], 'obj1': 'train', 'obj2': 'tree', 'relationship': 'behind'}, 'positive': '7122312237_9bcee2bd5c_o.jpg', 'positive_details': {'bbox1': [34, 611, 225, 478], 'bbox2': [356, 432, 3, 610], 'obj1': 'person', 'obj2': 'counter', 'relationship': 'behind'}, 'negative': '6883648073_b7ce5d4559_b.jpg', 'negative_details': {'bbox1': [93, 569, 308, 1023], 'bbox2': [1, 286, 24, 176], 'obj1': 'train', 'obj2': 'tree', 'relationship': 'next to'}}, {'anchor': '5813297357_f210a455f9_b.jpg', 'anchor_details': {'bbox1': [506, 629, 496, 580], 'bbox2': [152, 540, 342, 648], 'obj1': 'glasses', 'obj2': 'person', 'relationship': 'behind'}, 'positive': '8083328809_07bf7cf343_b.jpg', 'positive_details': {'bbox1': [133, 484, 373, 675], 'bbox2': [37, 387, 276, 599], 'obj1': 'person', 'obj2': 'table', 'relationship': 'behind'}, 'negative': '9420171433_0c28ed5369_b.jpg', 'negative_details': {'bbox1': [1, 97, 796, 937], 'bbox2': [312, 465, 777, 839], 'obj1': 'glasses', 'obj2': 'person', 'relationship': 'under'}}, {'anchor': '5813297357_f210a455f9_b.jpg', 'anchor_details': {'bbox1': [585, 759, 1, 362], 'bbox2': [152, 540, 342, 648], 'obj1': 'plate', 'obj2': 'person', 'relationship': 'behind'}, 'positive': '8695776750_e9bff94482_b.jpg', 'positive_details': {'bbox1': [215, 382, 759, 1003], 'bbox2': [1, 331, 464, 986], 'obj1': 'tree', 'obj2': 'building', 'relationship': 'behind'}, 'negative': '9425058051_d588dca90a_o.jpg', 'negative_details': {'bbox1': [337, 370, 352, 428], 'bbox2': [134, 438, 426, 608], 'obj1': 'plate', 'obj2': 'person', 'relationship': 'next to'}}, {'anchor': '5974460198_10b797c5dc_b.jpg', 'anchor_details': {'bbox1': [599, 995, 259, 590], 'bbox2': [217, 702, 204, 584], 'obj1': 'laptop', 'obj2': 'monitor', 'relationship': 'behind'}, 'positive': '243443773_57ad5437b6_o.jpg', 'positive_details': {'bbox1': [695, 748, 317, 375], 'bbox2': [674, 745, 361, 410], 'obj1': 'person', 'obj2': 'person', 'relationship': 'behind'}, 'negative': '4190437672_4f4a75837a_b.jpg', 'negative_details': {'bbox1': [419, 521, 139, 304], 'bbox2': [347, 474, 165, 299], 'obj1': 'laptop', 'obj2': 'monitor', 'relationship': 'next to'}}, {'anchor': '3362101674_5574f12cb2_b.jpg', 'anchor_details': {'bbox1': [134, 767, 263, 679], 'bbox2': [56, 274, 534, 681], 'obj1': 'person', 'obj2': 'lamp', 'relationship': 'behind'}, 'positive': '7174270492_0c572979d2_b.jpg', 'positive_details': {'bbox1': [578, 684, 284, 619], 'bbox2': [194, 586, 375, 728], 'obj1': 'bus', 'obj2': 'building', 'relationship': 'behind'}, 'negative': '8689104212_5d5d6f61b9_b.jpg', 'negative_details': {'bbox1': [377, 477, 230, 282], 'bbox2': [318, 486, 252, 353], 'obj1': 'person', 'obj2': 'lamp', 'relationship': 'next to'}}, {'anchor': '3362101674_5574f12cb2_b.jpg', 'anchor_details': {'bbox1': [315, 757, 3, 398], 'bbox2': [365, 474, 48, 151], 'obj1': 'person', 'obj2': 'basket', 'relationship': 'behind'}, 'positive': '7174270492_0c572979d2_b.jpg', 'positive_details': {'bbox1': [530, 767, 593, 1022], 'bbox2': [578, 684, 284, 619], 'obj1': 'bus', 'obj2': 'bus', 'relationship': 'behind'}, 'negative': '2985724718_50193b6167_b.jpg', 'negative_details': {'bbox1': [159, 684, 618, 770], 'bbox2': [614, 683, 874, 950], 'obj1': 'person', 'obj2': 'basket', 'relationship': 'next to'}}, {'anchor': '470440265_7c5367260f_b.jpg', 'anchor_details' ...

# %%
on_train_triplets=create_triplets(on_train)
# Out:
# 2701

# %%
under_train_triplets=create_triplets(under_train)
# Out:
# 578

# %%
next_to_train_triplets=create_triplets(next_to_train)
# Out:
# 2096

# %%
# !wget http://imagenet.stanford.edu/internal/jcjohns/scene_graphs/sg_dataset.zip
# Out:
# --2019-12-02 23:29:02--  http://imagenet.stanford.edu/internal/jcjohns/scene_graphs/sg_dataset.zip
# Resolving imagenet.stanford.edu (imagenet.stanford.edu)... 171.64.68.16
# Connecting to imagenet.stanford.edu (imagenet.stanford.edu)|171.64.68.16|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2000609775 (1.9G) [application/zip]
# Saving to: ‘sg_dataset.zip’
#
# sg_dataset.zip      100%[===================>]   1.86G  7.71MB/s    in 4m 27s
#
# 2019-12-02 23:33:29 (7.14 MB/s) - ‘sg_dataset.zip’ saved [2000609775/2000609775]

# %%
# !unzip sg_dataset.zip
# Out:
# Archive:  sg_dataset.zip
#    creating: sg_dataset/
#   inflating: sg_dataset/sg_test_annotations.json
#    creating: sg_dataset/sg_test_images/
#   inflating: sg_dataset/sg_test_images/10002158834_6dd6c6667f_b.jpg
#   inflating: sg_dataset/sg_test_images/10003466765_d20a7655c6_b.jpg
#   inflating: sg_dataset/sg_test_images/10008170616_a54deca9e3_b.jpg
#   inflating: sg_dataset/sg_test_images/10050248663_2cdb49c115_b.jpg
#   inflating: sg_dataset/sg_test_images/1006083276_0c1a4345fb_o.jpg
#   inflating: sg_dataset/sg_test_images/10085008474_8d72a9dc5e_b.jpg
#   inflating: sg_dataset/sg_test_images/10104268563_965a646010_b.jpg
#   inflating: sg_dataset/sg_test_images/10132007626_6421a783be_b.jpg
#   inflating: sg_dataset/sg_test_images/10132084253_cfa22219a1_b.jpg
#   inflating: sg_dataset/sg_test_images/10142659205_1158853119_b.jpg
#   inflating: sg_dataset/sg_test_images/10142737776_a40de33ab1_b.jpg
#   inflating: sg_dataset/sg_test_images/10161340284_8a72090a5b_b.jpg
#   inflating: sg_dataset/sg_test_images/10222607015_c4520dd0b2_b.jpg
#   inflating: sg_dataset/sg_test_images/10232487363_57bd85aacc_o.jpg
#   inflating: sg_dataset/sg_test_images/10298454133_85b077c4c0_b.jpg
#   inflating: sg_dataset/sg_test_images/105653920_281f69a5bb_b.jpg
#   inflating: sg_dataset/sg_test_images/1074602760_c1fc5a185e_b.jpg
#   inflating: sg_dataset/sg_test_images/108366605_aaab73a382_b.jpg
#   inflating: sg_dataset/sg_test_images/111083560_d11369b21d_b.jpg
#   inflating: sg_dataset/sg_test_images/114198969_e7ab432b8e_b.jpg
#   inflating: sg_dataset/sg_test_images/116298453_57a957315a_o.jpg
#   inflating: sg_dataset/sg_test_images/123622772_e15775d329_o.jpg
#   inflating: sg_dataset/sg_test_images/1269554185_dd621eb4e1_o.jpg
#   inflating: sg_dataset/sg_test_images/1281464762_3c5abbb0cd_b.jpg
#   inflating: sg_dataset/sg_test_images/130928209_e189846e06_o.jpg
#   inflating: sg_dataset/sg_test_images/1333583060_82dd7f754c_b.jpg
#   inflating: sg_dataset/sg_test_images/135298963_83209c3e6a_o.jpg
#   inflating: sg_dataset/sg_test_images/136745115_88a3f6e05c_b.jpg
#   inflating: sg_dataset/sg_test_images/139185650_464f5f6837_b.jpg
#   inflating: sg_dataset/sg_test_images/1393058209_3b765e68c7_b.jpg
#   inflating: sg_dataset/sg_test_images/141099010_e59a15d3a2_b.jpg
#   inflating: sg_dataset/sg_test_images/141509725_7710bf4cd3_o.jpg
#   inflating: sg_dataset/sg_test_images/1419753062_3c2b6845de_b.jpg
#   inflating: sg_dataset/sg_test_images/1427250326_b15b4f537b_b.jpg
#   inflating: sg_dataset/sg_test_images/1434786968_67ee1f0eaf_b.jpg
#   inflating: sg_dataset/sg_test_images/1441389240_b6b98de347_b.jpg
#   inflating: sg_dataset/sg_test_images/145671186_e44c79795e_o.jpg
#   inflating: sg_dataset/sg_test_images/147639012_cb755b6163_o.jpg
#   inflating: sg_dataset/sg_test_images/1488813756_4392034bc0_o.jpg
#   inflating: sg_dataset/sg_test_images/149706324_c1893ca2be_b.jpg
#   inflating: sg_dataset/sg_test_images/1497493960_38538d32e7_b.jpg
#   inflating: sg_dataset/sg_test_images/1504849269_7dd4fb6a7a_o.jpg
#   inflating: sg_dataset/sg_test_images/1525522431_0cad9b0fa5_b.jpg
#   inflating: sg_dataset/sg_test_images/154453908_727e3fab2e_b.jpg
#   inflating: sg_dataset/sg_test_images/155149707_f7b5373dba_b.jpg
#   inflating: sg_dataset/sg_test_images/156364891_11a7cd070e_b.jpg
#   inflating: sg_dataset/sg_test_images/157595351_6326f90542_o.jpg
#   inflating: sg_dataset/sg_test_images/161638840_4de67b36c9_o.jpg
#   inflating: sg_dataset/sg_test_images/16444142_53c59dcd22_o.jpg
#   inflating: sg_dataset/sg_test_images/173243671_7846aca311_b.jpg
#   inflating: sg_dataset/sg_test_images/174196276_8a9cc595cf_b.jpg
#   inflating: sg_dataset/sg_test_images/177941036_5bf2f82044_b.jpg
#   inflating: sg_dataset/sg_test_images/180202155_a86312fa71_o.jpg
#   inflating: sg_dataset/sg_test_images/19014116_fbde61c01e_b.jpg
#   inflating: sg_dataset/sg_test_images/190789903_bfc2632165_b.jpg
#   inflating: sg_dataset/sg_test_images/194654941_052c0bd67f_o.jpg
#   inflating: sg_dataset/sg_test_images/194967296_38bf7abb48_b.jpg
#   inflating: sg_dataset/sg_test_images/19558736_62d4cc76b8_o.jpg
#   inflating: sg_dataset/sg_test_images/199028894_013b7ad81d_b.jpg
#   inflating: sg_dataset/sg_test_images/2042318968_180c66dc4a_b.jpg
#   inflating: sg_dataset/sg_test_images/2046901560_e63c457e1a_o.jpg
#   inflating: sg_dataset/sg_test_images/205164508_5759e0151e_b.jpg
#   inflating: sg_dataset/sg_test_images/205314862_8ede66b486_b.jpg
#   inflating: sg_dataset/sg_test_images/2065044967_f6400506d7_b.jpg
#   inflating: sg_dataset/sg_test_images/2071742733_e2d253437b_o.jpg
#   inflating: sg_dataset/sg_test_images/207210088_417f9f054d_b.jpg
#   inflating: sg_dataset/sg_test_images/2074418083_0ceea444a4_b.jpg
#   inflating: sg_dataset/sg_test_images/2084710251_92574f8f73_b.jpg
#   inflating: sg_dataset/sg_test_images/2100138665_e6410ec0f3_b.jpg
#   inflating: sg_dataset/sg_test_images/2107436863_01570419d2_b.jpg
#   inflating: sg_dataset/sg_test_images/2123745830_ef0b35bd69_b.jpg
#   inflating: sg_dataset/sg_test_images/2133667892_c722113eb4_b.jpg
#   inflating: sg_dataset/sg_test_images/213579802_f4c00b3420_b.jpg
#   inflating: sg_dataset/sg_test_images/2136747174_ab0d432c52_b.jpg
#   inflating: sg_dataset/sg_test_images/2140019357_cd002f37fe_b.jpg
#   inflating: sg_dataset/sg_test_images/2156631431_203650eb6e_b.jpg
#   inflating: sg_dataset/sg_test_images/216121118_e7b869c77e_b.jpg
#   inflating: sg_dataset/sg_test_images/2162817251_c1abea59f8_b.jpg
#   inflating: sg_dataset/sg_test_images/2163160471_fe12fb0ca6_b.jpg
#   inflating: sg_dataset/sg_test_images/2209527322_5f2e586ec8_o.jpg
#   inflating: sg_dataset/sg_test_images/2214032574_c8b2d7ca9a_b.jpg
#   inflating: sg_dataset/sg_test_images/2218603910_84281e9592_b.jpg
#   inflating: sg_dataset/sg_test_images/222436779_4c4d3e7824_b.jpg
#   inflating: sg_dataset/sg_test_images/222852973_5f50710489_o.jpg
#   inflating: sg_dataset/sg_test_images/2242034214_9f9210b62f_b.jpg
#   inflating: sg_dataset/sg_test_images/2247097262_1fe9a59d8a_b.jpg
#   inflating: sg_dataset/sg_test_images/2254023062_7cafa36021_b.jpg
#   inflating: sg_dataset/sg_test_images/2254501857_d5c8984396_b.jpg
#   inflating: sg_dataset/sg_test_images/2259330726_76e4731476_b.jpg
#   inflating: sg_dataset/sg_test_images/228222448_96ae4e4e91_b.jpg
#   inflating: sg_dataset/sg_test_images/2287052188_f232471fd9_b.jpg
#   inflating: sg_dataset/sg_test_images/230006143_27bdbfd79d_o.jpg
#   inflating: sg_dataset/sg_test_images/2304707627_0e3931b372_b.jpg
#   inflating: sg_dataset/sg_test_images/2305276033_c59531bd41_b.jpg
#   inflating: sg_dataset/sg_test_images/2315425426_e246d4483f_b.jpg
#   inflating: sg_dataset/sg_test_images/231945478_1d01e6df14_o.jpg
#   inflating: sg_dataset/sg_test_images/232107806_4c5756fe0f_o.jpg
#   inflating: sg_dataset/sg_test_images/2332887765_9ed316f6df_b.jpg
#   inflating: sg_dataset/sg_test_images/2343988204_1c0b96434d_b.jpg
#   inflating: sg_dataset/sg_test_images/2347297994_2b9132597b_o.jpg
#   inflating: sg_dataset/sg_test_images/2393973731_1fe2908280_o.jpg
#   inflating: sg_dataset/sg_test_images/2394762096_199450ccdf_b.jpg
#   inflating: sg_dataset/sg_test_images/2421762255_e3251311a2_b.jpg
#   inflating: sg_dataset/sg_test_images/2459989965_2862761f2f_o.jpg
#   inflating: sg_dataset/sg_test_images/246934041_1029ed3032_b.jpg
#   inflating: sg_dataset/sg_test_images/247203572_ae8a769834_o.jpg
#   inflating: sg_dataset/sg_test_images/2484981229_5c8f09bc9d_b.jpg
#   inflating: sg_dataset/sg_test_images/248993928_9aa5dc42c4_b.jpg
#   inflating: sg_dataset/sg_test_images/2504169523_efaf5a860d_b.jpg
#   inflating: sg_dataset/sg_test_images/2509623843_4ac6ef95c5_o.jpg
#   inflating: sg_dataset/sg_test_images/2509842384_c484eef934_b.jpg
#   inflating: sg_dataset/sg_test_images/253724899_22356683f5_b.jpg
#   inflating: sg_dataset/sg_test_images/2537791844_51f99823b6_b.jpg
#   inflating: sg_dataset/sg_test_images/2538004422_235c9a6333_o.jpg
#   inflating: sg_dataset/sg_test_images/2555357520_5fce36cf09_b.jpg
#   inflating: sg_dataset/sg_test_images/2556788601_16b84d297f_b.jpg
#   inflating: sg_dataset/sg_test_images/2569402304_4bf0952216_o.jpg
#   inflating: sg_dataset/sg_test_images/2569508118_9639b8fbdf_b.jpg
#   inflating: sg_dataset/sg_test_images/2580978375_43b4ef0fd8_b.jpg
#   inflating: sg_dataset/sg_test_images/2584263186_3969c8a53e_b.jpg
#   inflating: sg_dataset/sg_test_images/2610019025_6fbc44e1b3_o.jpg
#   inflating: sg_dataset/sg_test_images/2619522027_879221dacb_b.jpg
#   inflating: sg_dataset/sg_test_images/2626182987_8388ec27b4_b.jpg
#   inflating: sg_dataset/sg_test_images/2632235877_6e83eb1395_b.jpg
#   inflating: sg_dataset/sg_test_images/2646539163_f11cc5d822_b.jpg
#   inflating: sg_dataset/sg_test_images/2646977984_c2af772349_b.jpg
#   inflating: sg_dataset/sg_test_images/2666551000_110164f6a8_b.jpg
#   inflating: sg_dataset/sg_test_images/2668102257_9fabeeaecb_b.jpg
#   inflating: sg_dataset/sg_test_images/267185337_7029122491_b.jpg
#   inflating: sg_dataset/sg_test_images/2673390193_e53a38fc64_o.jpg
#   inflating: sg_dataset/sg_test_images/2689480291_da33da0844_o.jpg
#   inflating: sg_dataset/sg_test_images/2705280504_0a0cf4417b_b.jpg
#   inflating: sg_dataset/sg_test_images/2709242719_468bf83e9f_b.jpg
#   inflating: sg_dataset/sg_test_images/2725539064_770423934a_b.jpg
#   inflating: sg_dataset/sg_test_images/2743361338_3d1a1e3b93_o.png
#   inflating: sg_dataset/sg_test_images/2775199795_aefb58fc83_b.jpg
#   inflating: sg_dataset/sg_test_images/2794275768_52a64c9f18_o.jpg
#   inflating: sg_dataset/sg_test_images/2801678879_a482994b9f_o.jpg
#   inflating: sg_dataset/sg_test_images/2814762654_ea6e7c92b5_b.jpg
#   inflating: sg_dataset/sg_test_images/2814890707_535fb50170_b.jpg
#   inflating: sg_dataset/sg_test_images/2820743071_dae064f6e7_o.jpg
#   inflating: sg_dataset/sg_test_images/2829187185_5985cb281a_b.jpg
#   inflating: sg_dataset/sg_test_images/2829415858_cd75f39623_b.jpg
#   inflating: sg_dataset/sg_test_images/2832592525_d5c7be214e_o.jpg
#   inflating: sg_dataset/sg_test_images/2840387645_40c76fdd03_o.jpg
#   inflating: sg_dataset/sg_test_images/2850786338_b0ec05cc57_b.jpg
#   inflating: sg_dataset/sg_test_images/285828762_e119673135_b.jpg
#   inflating: sg_dataset/sg_test_images/2876425753_911f5db9e0_b.jpg
#   inflating: sg_dataset/sg_test_images/2879898254_1620bb8c5a_b.jpg
#   inflating: sg_dataset/sg_test_images/2912393682_f13368ef5c_b.jpg
#   inflating: sg_dataset/sg_test_images/29317143_99a1ad7438_b.jpg
#   inflating: sg_dataset/sg_test_images/2940172970_3f0d3a4a65_b.jpg
#   inflating: sg_dataset/sg_test_images/294962708_623dc44bf8_b.jpg
#   inflating: sg_dataset/sg_test_images/296481324_5c89ea6b7e_b.jpg
#   inflating: sg_dataset/sg_test_images/2971251148_d241e54ae2_b.jpg
#   inflating: sg_dataset/sg_test_images/2972941961_7c80b7c9e6_o.jpg
#   inflating: sg_dataset/sg_test_images/297985541_b200edfd05_b.jpg
#   inflating: sg_dataset/sg_test_images/2987392711_42e26d9802_b.jpg
#   inflating: sg_dataset/sg_test_images/299729601_31909c71d8_b.jpg
#   inflating: sg_dataset/sg_test_images/303330535_ed0dd66464_o.jpg
#   inflating: sg_dataset/sg_test_images/3038755837_69e4a5571d_b.jpg
#   inflating: sg_dataset/sg_test_images/3039022906_b4975f1451_b.jpg
#   inflating: sg_dataset/sg_test_images/306542674_5e87198783_b.jpg
#   inflating: sg_dataset/sg_test_images/306862340_546ece8751_b.jpg
#   inflating: sg_dataset/sg_test_images/3075720505_529ae34cda_b.jpg
#   inflating: sg_dataset/sg_test_images/3089798484_419c76ec2c_o.jpg
#   inflating: sg_dataset/sg_test_images/3097503247_0bd80bac9f_o.jpg
#   inflating: sg_dataset/sg_test_images/310142483_c26590e47c_o.jpg
#   inflating: sg_dataset/sg_test_images/311802141_0e36251eb2_o.jpg
#   inflating: sg_dataset/sg_test_images/3118739499_efaec26e16_o.jpg
#   inflating: sg_dataset/sg_test_images/3131916266_569965d104_b.jpg
#   inflating: sg_dataset/sg_test_images/3138283150_2a1527e025_b.jpg
#   inflating: sg_dataset/sg_test_images/3155998575_2507bd136f_o.jpg
#   inflating: sg_dataset/sg_test_images/3163440231_f04575fc51_o.jpg
#   inflating: sg_dataset/sg_test_images/3166538450_82062c6347_o.jpg
#   inflating: sg_dataset/sg_test_images/3186048325_17f7b2428a_b.jpg
#   inflating: sg_dataset/sg_test_images/318779251_bf6fc9408d_o.jpg
#   inflating: sg_dataset/sg_test_images/319629473_aab7f52dc6_b.jpg
#   inflating: sg_dataset/sg_test_images/3219144298_0f5132a020_b.jpg
#   inflating: sg_dataset/sg_test_images/3222889497_e2f3c59fb9_b.jpg
#   inflating: sg_dataset/sg_test_images/3225414118_281e58dfa6_b.jpg
#   inflating: sg_dataset/sg_test_images/324885996_fbda2fc462_o.jpg
#   inflating: sg_dataset/sg_test_images/3253384558_39130e6a48_o.jpg
#   inflating: sg_dataset/sg_test_images/3260842681_f2cf93104e_b.jpg
#   inflating: sg_dataset/sg_test_images/3266107604_245328e89f_b.jpg
#   inflating: sg_dataset/sg_test_images/327080147_af85d8c832_o.jpg
#   inflating: sg_dataset/sg_test_images/3288039692_a93da3df2f_o.jpg
#   inflating: sg_dataset/sg_test_images/3324795132_27da13ff9b_b.jpg
#   inflating: sg_dataset/sg_test_images/3337409302_e0f9abc621_b.jpg
#   inflating: sg_dataset/sg_test_images/3340263766_18980e1d37_b.jpg
#   inflating: sg_dataset/sg_test_images/3342426954_a9ddfd915b_b.jpg
#   inflating: sg_dataset/sg_test_images/3345907813_21b6a8ff71_b.jpg
#   inflating: sg_dataset/sg_test_images/3353263153_1dc0005906_o.jpg
#   inflating: sg_dataset/sg_test_images/3367477595_9993f46b38_b.jpg
#   inflating: sg_dataset/sg_test_images/3373056123_8fd7fb0365_b.jpg
#   inflating: sg_dataset/sg_test_images/3373981469_ffd1671db8_b.jpg
#   inflating: sg_dataset/sg_test_images/3384568614_5f398f4cf6_b.jpg
#   inflating: sg_dataset/sg_test_images/3386170394_c117fa9f15_o.jpg
#   inflating: sg_dataset/sg_test_images/34041643_61910492ae_b.jpg
#   inflating: sg_dataset/sg_test_images/3407689174_2a183e5464_b.jpg
#   inflating: sg_dataset/sg_test_images/3429278407_dd8a3e748c_b.jpg
#   inflating: sg_dataset/sg_test_images/3454799233_59e3a7b741_o.jpg
#   inflating: sg_dataset/sg_test_images/3456395216_241896cfc9_b.jpg
#   inflating: sg_dataset/sg_test_images/3457340547_b67ae78eaf_b.jpg
#   inflating: sg_dataset/sg_test_images/3469000344_110a9cdd6a_b.jpg
#   inflating: sg_dataset/sg_test_images/3475008499_d13466f1f1_b.jpg
#   inflating: sg_dataset/sg_test_images/3489052815_d898c1e171_o.jpg
#   inflating: sg_dataset/sg_test_images/34893383_69ffe89526_o.jpg
#   inflating: sg_dataset/sg_test_images/3503534063_39f589a065_b.jpg
#   inflating: sg_dataset/sg_test_images/353214581_cc55760179_o.jpg
#   inflating: sg_dataset/sg_test_images/35355235_8955a0569b_o.jpg
#   inflating: sg_dataset/sg_test_images/3536558797_6e1eef4591_b.jpg
#   inflating: sg_dataset/sg_test_images/3557337965_1e86a11591_o.jpg
#   inflating: sg_dataset/sg_test_images/3568995746_d9685368b1_b.jpg
#   inflating: sg_dataset/sg_test_images/3576254603_e2c6275ac2_b.jpg
#   inflating: sg_dataset/sg_test_images/3578489233_caacd6f90b_b.jpg
#   inflating: sg_dataset/sg_test_images/3579390717_42018f3270_o.jpg
#   inflating: sg_dataset/sg_test_images/3584173064_a586d11faf_b.jpg
#   inflating: sg_dataset/sg_test_images/3584337772_8b79dd6e4c_o.jpg
#   inflating: sg_dataset/sg_test_images/3589847900_0d9a479597_b.jpg
#   inflating: sg_dataset/sg_test_images/3614203450_8e6e0e3f05_b.jpg
#   inflating: sg_dataset/sg_test_images/3614337241_d5046daa46_b.jpg
#   inflating: sg_dataset/sg_test_images/362154704_40edaae16c_b.jpg
#   inflating: sg_dataset/sg_test_images/3635689871_b6c9c4bdff_b.jpg
#   inflating: sg_dataset/sg_test_images/363891681_524e9ce77d_b.jpg
#   inflating: sg_dataset/sg_test_images/3641988827_700dcf69e5_o.jpg
#   inflating: sg_dataset/sg_test_images/3652129919_0efc9b55f6_b.jpg
#   inflating: sg_dataset/sg_test_images/3663106077_e332d132c8_b.jpg
#   inflating: sg_dataset/sg_test_images/3665708190_b99175077d_o.jpg
#   inflating: sg_dataset/sg_test_images/3696874688_9777c451f0_b.jpg
#   inflating: sg_dataset/sg_test_images/3706601540_e992559367_b.jpg
#   inflating: sg_dataset/sg_test_images/3713237457_fdbfccf903_b.jpg
#   inflating: sg_dataset/sg_test_images/3715130314_1a24601c7e_b.jpg
#   inflating: sg_dataset/sg_test_images/3721780236_8ab1f1c7a0_o.jpg
#   inflating: sg_dataset/sg_test_images/3732568219_585f6efb46_b.jpg
#   inflating: sg_dataset/sg_test_images/3737497401_10c11840e1_b.jpg
#   inflating: sg_dataset/sg_test_images/3742232385_0e12e54263_b.jpg
#   inflating: sg_dataset/sg_test_images/3742635376_be5816b6b6_b.jpg
#   inflating: sg_dataset/sg_test_images/374988762_a9b44a4508_b.jpg
#   inflating: sg_dataset/sg_test_images/3750170274_1d78863f95_b.jpg
#   inflating: sg_dataset/sg_test_images/3766609982_7008d5084f_b.jpg
#   inflating: sg_dataset/sg_test_images/3772244895_1c793c5a8e_o.jpg
#   inflating: sg_dataset/sg_test_images/3776124784_d4dc09fd82_b.jpg
#   inflating: sg_dataset/sg_test_images/37848607_cb4c8d84f2_b.jpg
#   inflating: sg_dataset/sg_test_images/3787246396_9bf2b63c6b_b.jpg
#   inflating: sg_dataset/sg_test_images/3793855385_41ae000a71_b.jpg
#   inflating: sg_dataset/sg_test_images/3794327665_f915a241d3_b.jpg
#   inflating: sg_dataset/sg_test_images/3794893317_d714a9a4f8_b.jpg
#   inflating: sg_dataset/sg_test_images/3801028227_c7a33bbc17_b.jpg
#   inflating: sg_dataset/sg_test_images/3825251524_aa09a332ec_b.jpg
#   inflating: sg_dataset/sg_test_images/3825256896_c2d83ba5b9_b.jpg
#   inflating: sg_dataset/sg_test_images/3827567409_4493f3704a_o.jpg
#   inflating: sg_dataset/sg_test_images/383936660_0e10f40e00_o.jpg
#   inflating: sg_dataset/sg_test_images/3842344397_f87da45ab1_b.jpg
#   inflating: sg_dataset/sg_test_images/3842390830_f99539c780_b.jpg
#   inflating: sg_dataset/sg_test_images/38457647_011d630cc1_o.jpg
#   inflating: sg_dataset/sg_test_images/3845770407_1a8cd41230_b.jpg
#   inflating: sg_dataset/sg_test_images/3849606438_ec488ff23e_b.jpg
#   inflating: sg_dataset/sg_test_images/3853390560_e4f402b1d0_b.jpg
#   inflating: sg_dataset/sg_test_images/3874039121_022e2fb791_b.jpg
#   inflating: sg_dataset/sg_test_images/387924004_6191257ab9_o.jpg
#   inflating: sg_dataset/sg_test_images/3880099022_49ec03e698_o.jpg
#   inflating: sg_dataset/sg_test_images/3882370446_37f2d5cbbf_b.jpg
#   inflating: sg_dataset/sg_test_images/3887797687_ca4a017b6c_b.jpg
#   inflating: sg_dataset/sg_test_images/3902018998_1e5933bc78_o.jpg
#   inflating: sg_dataset/sg_test_images/3903095433_6a62ea473b_b.jpg
#   inflating: sg_dataset/sg_test_images/3910986411_e58498fc61_b.jpg
#   inflating: sg_dataset/sg_test_images/3911635467_3bac092661_b.jpg
#   inflating: sg_dataset/sg_test_images/3914049811_cdb70ca0ab_b.jpg
#   inflating: sg_dataset/sg_test_images/3920514049_a20cfebd62_b.jpg
#   inflating: sg_dataset/sg_test_images/3976112836_6f6e418a30_o.jpg
#   inflating: sg_dataset/sg_test_images/3977856338_3cba7fc321_o.jpg
#   inflating: sg_dataset/sg_test_images/3982230222_c908aa4601_b.jpg
#   inflating: sg_dataset/sg_test_images/3987934391_ffec860739_b.jpg
#   inflating: sg_dataset/sg_test_images/3988529173_9c88fa79cd_b.jpg
#   inflating: sg_dataset/sg_test_images/3998983910_3fe5799db4_b.jpg
#   inflating: sg_dataset/sg_test_images/4039008800_ec628e2ba9_b.jpg
#   inflating: sg_dataset/sg_test_images/4039370394_4e1847fe41_b.jpg
#   inflating: sg_dataset/sg_test_images/4044120852_e865b5ca92_b.jpg
#   inflating: sg_dataset/sg_test_images/405314222_af8f564013_o.jpg
#   inflating: sg_dataset/sg_test_images/406487012_65aed1faa7_o.jpg
#   inflating: sg_dataset/sg_test_images/4071468982_fd438e9c83_b.jpg
#   inflating: sg_dataset/sg_test_images/4085049_2fda7bc44b_o.jpg
#   inflating: sg_dataset/sg_test_images/408738721_8ec695ce55_o.jpg
#   inflating: sg_dataset/sg_test_images/4126242775_1ffef299e8_o.jpg
#   inflating: sg_dataset/sg_test_images/4136904744_424ee7ea36_b.jpg
#   inflating: sg_dataset/sg_test_images/4137217003_bc1bd860c0_o.jpg
#   inflating: sg_dataset/sg_test_images/4150090398_6a7d30fb0a_b.jpg
#   inflating: sg_dataset/sg_test_images/4150251905_9185fdd5e6_o.jpg
#   inflating: sg_dataset/sg_test_images/4150504250_c331366673_b.jpg
#   inflating: sg_dataset/sg_test_images/4155560684_cda3027d56_o.jpg
#   inflating: sg_dataset/sg_test_images/415673256_22097c2605_o.jpg
#   inflating: sg_dataset/sg_test_images/4173816642_bbe11eee82_b.jpg
#   inflating: sg_dataset/sg_test_images/4177290532_e9068e0925_b.jpg
#   inflating: sg_dataset/sg_test_images/4192626071_8f54f4578e_b.jpg
#   inflating: sg_dataset/sg_test_images/4199268029_5bb4b7752f_b.jpg
#   inflating: sg_dataset/sg_test_images/4202064507_2ea3082751_b.jpg
#   inflating: sg_dataset/sg_test_images/4205648420_a78d955dec_o.jpg
#   inflating: sg_dataset/sg_test_images/4213963259_59b213a0b1_b.jpg
#   inflating: sg_dataset/sg_test_images/4225675344_a732bbd5ae_b.jpg
#   inflating: sg_dataset/sg_test_images/424982680_5a7f530748_b.jpg
#   inflating: sg_dataset/sg_test_images/4253896157_8684609ebe_b.jpg
#   inflating: sg_dataset/sg_test_images/425517965_8e762fb24f_b.jpg
#   inflating: sg_dataset/sg_test_images/4260541002_4e8b2426b5_b.jpg
#   inflating: sg_dataset/sg_test_images/4260566643_0d6568fa27_b.jpg
#   inflating: sg_dataset/sg_test_images/4261013291_3b8dde9243_o.jpg
#   inflating: sg_dataset/sg_test_images/4265229058_7eed6cd5c8_b.jpg
#   inflating: sg_dataset/sg_test_images/4266974685_16ab5a5e48_b.jpg
#   inflating: sg_dataset/sg_test_images/4278784501_a20863fb3f_o.jpg
#   inflating: sg_dataset/sg_test_images/4280965360_3205355088_b.jpg
#   inflating: sg_dataset/sg_test_images/4282356534_674cd2ac4d_b.jpg
#   inflating: sg_dataset/sg_test_images/4291251243_9f911b1652_b.jpg
#   inflating: sg_dataset/sg_test_images/4294796626_17358688cb_b.jpg
#   inflating: sg_dataset/sg_test_images/4294886367_a5a663e163_o.jpg
#   inflating: sg_dataset/sg_test_images/4294972983_35f43cf97f_b.jpg
#   inflating: sg_dataset/sg_test_images/4305290071_fd01a37cf7_b.jpg
#   inflating: sg_dataset/sg_test_images/4314224115_10727fea00_o.jpg
#   inflating: sg_dataset/sg_test_images/43161051_a32a288f14_b.jpg
#   inflating: sg_dataset/sg_test_images/4320348647_f6c06a3cd5_b.jpg
#   inflating: sg_dataset/sg_test_images/4323572126_5840a858a5_b.jpg
#   inflating: sg_dataset/sg_test_images/4327585910_5c31ac88be_b.jpg
#   inflating: sg_dataset/sg_test_images/4331364162_3bf9564426_b.jpg
#   inflating: sg_dataset/sg_test_images/4331959222_44e31e269e_b.jpg
#   inflating: sg_dataset/sg_test_images/4342374691_6aa9369060_b.jpg
#   inflating: sg_dataset/sg_test_images/4344232677_956ae04491_b.jpg
#   inflating: sg_dataset/sg_test_images/434559923_aa5e4a7f33_b.jpg
#   inflating: sg_dataset/sg_test_images/4346438294_3e50a384ce_o.jpg
#   inflating: sg_dataset/sg_test_images/4347518965_17a6a8e2e9_b.jpg
#   inflating: sg_dataset/sg_test_images/4356745626_ab836014aa_o.jpg
#   inflating: sg_dataset/sg_test_images/4357208606_ce0f096a70_b.jpg
#   inflating: sg_dataset/sg_test_images/4370372957_91f0753201_b.jpg
#   inflating: sg_dataset/sg_test_images/4371713365_abf9fc9216_b.jpg
#   inflating: sg_dataset/sg_test_images/4385206582_c333f18635_b.jpg
#   inflating: sg_dataset/sg_test_images/4385891066_394e99c248_b.jpg
#   inflating: sg_dataset/sg_test_images/4392556686_44d71ff5a0_o.gif
#   inflating: sg_dataset/sg_test_images/4407337743_22edebafb6_o.jpg
#   inflating: sg_dataset/sg_test_images/4418514401_cd86bc8e53_b.jpg
#   inflating: sg_dataset/sg_test_images/4421433563_89e8f76c6e_b.jpg
#   inflating: sg_dataset/sg_test_images/442331963_fdb537fb4d_o.jpg
#   inflating: sg_dataset/sg_test_images/4426833896_d25e27da63_b.jpg
#   inflating: sg_dataset/sg_test_images/4428737665_7627efc310_b.jpg
#   inflating: sg_dataset/sg_test_images/4435536063_77d6d2136e_o.jpg
#   inflating: sg_dataset/sg_test_images/4451473528_e2c3a6d1dd_b.jpg
#   inflating: sg_dataset/sg_test_images/4452442400_021f0599f8_b.jpg
#   inflating: sg_dataset/sg_test_images/4454351244_9bef41c9fe_o.jpg
#   inflating: sg_dataset/sg_test_images/4465569739_17d013f6d3_b.jpg
#   inflating: sg_dataset/sg_test_images/4476156838_b12470a01c_b.jpg
#   inflating: sg_dataset/sg_test_images/447938528_e5ac4e9448_b.jpg
#   inflating: sg_dataset/sg_test_images/4487608653_2a1fbdb3cb_b.jpg
#   inflating: sg_dataset/sg_test_images/4500881088_1ab8bb68f3_o.jpg
#   inflating: sg_dataset/sg_test_images/4503984838_8b94fb94a5_b.jpg
#   inflating: sg_dataset/sg_test_images/450418842_becf7172c1_o.jpg
#   inflating: sg_dataset/sg_test_images/451181925_7e12d1f7f8_b.jpg
#   inflating: sg_dataset/sg_test_images/4513379791_76a3800b66_b.jpg
#   inflating: sg_dataset/sg_test_images/4513884834_c86879398b_b.jpg
#   inflating: sg_dataset/sg_test_images/451659066_e15e6f34d7_b.jpg
#   inflating: sg_dataset/sg_test_images/4518345389_57a4fecbb9_b.jpg
#   inflating: sg_dataset/sg_test_images/4526855593_b41ae29eae_b.jpg
#   inflating: sg_dataset/sg_test_images/4537155739_85a527fc75_b.jpg
#   inflating: sg_dataset/sg_test_images/4537473706_65cf5e785b_o.jpg
#   inflating: sg_dataset/sg_test_images/454397389_9e90b62ddb_b.jpg
#   inflating: sg_dataset/sg_test_images/4548112138_1b934e209f_b.jpg
#   inflating: sg_dataset/sg_test_images/4552631826_e2d2ded534_o.jpg
#   inflating: sg_dataset/sg_test_images/45627517_86f79d0e07_o.jpg
#   inflating: sg_dataset/sg_test_images/4568193545_0a195114f7_b.jpg
#   inflating: sg_dataset/sg_test_images/4574420144_bae8886cc8_b.jpg
#   inflating: sg_dataset/sg_test_images/4577659528_01e4f18f09_b.jpg
#   inflating: sg_dataset/sg_test_images/4579361887_ed9c778b3c_b.jpg
#   inflating: sg_dataset/sg_test_images/459904676_67e49725fc_b.jpg
#   inflating: sg_dataset/sg_test_images/4607898043_b7e3262887_b.jpg
#   inflating: sg_dataset/sg_test_images/462147263_4b5b7fbfd3_b.jpg
#   inflating: sg_dataset/sg_test_images/463689893_adcca8f508_o.jpg
#   inflating: sg_dataset/sg_test_images/4646729667_eb327b6418_b.jpg
#   inflating: sg_dataset/sg_test_images/4668514133_66126b2ce2_b.jpg
#   inflating: sg_dataset/sg_test_images/4673724266_fc50223e54_b.jpg
#   inflating: sg_dataset/sg_test_images/4679659935_2cf8905ec5_b.jpg
#   inflating: sg_dataset/sg_test_images/4691208544_9e313cb449_b.jpg
#   inflating: sg_dataset/sg_test_images/469555156_ca7deb31b3_b.jpg
#   inflating: sg_dataset/sg_test_images/4698061679_1ae8c97b16_b.jpg
#   inflating: sg_dataset/sg_test_images/4699072944_b6ecfbeca7_b.jpg
#   inflating: sg_dataset/sg_test_images/4708482548_9b43da6777_b.jpg
#   inflating: sg_dataset/sg_test_images/4712249625_81fb69d50d_b.jpg
#   inflating: sg_dataset/sg_test_images/4713801724_3a874afde4_b.jpg
#   inflating: sg_dataset/sg_test_images/4723888023_010c646c7b_b.jpg
#   inflating: sg_dataset/sg_test_images/4728191205_cfdc3549b9_b.jpg
#   inflating: sg_dataset/sg_test_images/4742618533_679db34cd4_b.jpg
#   inflating: sg_dataset/sg_test_images/4748598087_fe65d988f7_b.jpg
#   inflating: sg_dataset/sg_test_images/4767824121_b4fa6ed73b_b.jpg
#   inflating: sg_dataset/sg_test_images/4774626044_d4870e5a3d_b.jpg
#   inflating: sg_dataset/sg_test_images/4788767927_236444fd03_b.jpg
#   inflating: sg_dataset/sg_test_images/4800567641_2e61175ff1_b.jpg
#   inflating: sg_dataset/sg_test_images/4801256648_d5522c5d60_b.jpg
#   inflating: sg_dataset/sg_test_images/4802813731_301a1f2371_b.jpg
#   inflating: sg_dataset/sg_test_images/4806585594_f8a9f49577_b.jpg
#   inflating: sg_dataset/sg_test_images/4812500977_3e79615b52_o.jpg
#   inflating: sg_dataset/sg_test_images/4813675025_7652eddd77_b.jpg
#   inflating: sg_dataset/sg_test_images/4814875474_6ae1c9a381_b.jpg
#   inflating: sg_dataset/sg_test_images/4833602735_1fdd9f522c_b.jpg
#   inflating: sg_dataset/sg_test_images/484589733_ff1afbfa25_b.jpg
#   inflating: sg_dataset/sg_test_images/4847012655_42e6263cfd_b.jpg
#   inflating: sg_dataset/sg_test_images/4878983785_c40828f725_b.jpg
#   inflating: sg_dataset/sg_test_images/4887164213_181a5ca26a_b.jpg
#   inflating: sg_dataset/sg_test_images/489058514_a74537034d_b.jpg
#   inflating: sg_dataset/sg_test_images/4915774151_dec63e724d_b.jpg
#   inflating: sg_dataset/sg_test_images/4925596469_57b2fe0ef5_b.jpg
#   inflating: sg_dataset/sg_test_images/4930772727_e17e3784c4_b.jpg
#   inflating: sg_dataset/sg_test_images/4966390970_6380d0c1a4_b.jpg
#   inflating: sg_dataset/sg_test_images/4978923025_d17e6e8e33_b.jpg
#   inflating: sg_dataset/sg_test_images/4979927771_6d32994354_b.jpg
#   inflating: sg_dataset/sg_test_images/4986938199_7be9a37d50_b.jpg
#   inflating: sg_dataset/sg_test_images/4988019688_d276d17466_b.jpg
#   inflating: sg_dataset/sg_test_images/4992466550_265d86a47c_b.jpg
#   inflating: sg_dataset/sg_test_images/4992656841_e8f3f51653_b.jpg
#   inflating: sg_dataset/sg_test_images/4998457984_76e77e8473_b.jpg
#   inflating: sg_dataset/sg_test_images/5000000882_f65fbf6ffa_b.jpg
#   inflating: sg_dataset/sg_test_images/500336501_2ab8bd519b_b.jpg
#   inflating: sg_dataset/sg_test_images/502516671_61032ccfbe_o.jpg
#   inflating: sg_dataset/sg_test_images/5029487385_08bc30de4b_b.jpg
#   inflating: sg_dataset/sg_test_images/503792217_6c18dd0251_o.jpg
#   inflating: sg_dataset/sg_test_images/5037939264_85b09258c0_b.jpg
#   inflating: sg_dataset/sg_test_images/5045708187_0a93c2c023_b.jpg
#   inflating: sg_dataset/sg_test_images/5046517526_eaafe2ffb6_b.jpg
#   inflating: sg_dataset/sg_test_images/5055414189_15af801e19_b.jpg
#   inflating: sg_dataset/sg_test_images/5064573447_7da6b6f30f_b.jpg
#   inflating: sg_dataset/sg_test_images/5082955965_1a3102693b_b.jpg
#   inflating: sg_dataset/sg_test_images/5089621941_083554ed09_b.jpg
#   inflating: sg_dataset/sg_test_images/5128150456_46605520bd_b.jpg
#   inflating: sg_dataset/sg_test_images/5140921498_84243d71cd_b.jpg
#   inflating: sg_dataset/sg_test_images/5150867807_c90e11e7d1_b.jpg
#   inflating: sg_dataset/sg_test_images/515453707_a5704f76b5_b.jpg
#   inflating: sg_dataset/sg_test_images/5159892039_1007298824_b.jpg
#   inflating: sg_dataset/sg_test_images/5173624489_34cb14ba85_b.jpg
#   inflating: sg_dataset/sg_test_images/5197098219_d55cd11285_b.jpg
#   inflating: sg_dataset/sg_test_images/5209477280_5bf65f67be_b.jpg
#   inflating: sg_dataset/sg_test_images/5210124743_3121e3e7e9_b.jpg
#   inflating: sg_dataset/sg_test_images/5217423633_9c2269df63_b.jpg
#   inflating: sg_dataset/sg_test_images/5219053386_16a6151347_b.jpg
#   inflating: sg_dataset/sg_test_images/5219749320_e5cea3f031_b.jpg
#   inflating: sg_dataset/sg_test_images/5241919318_d5f0640525_b.jpg
#   inflating: sg_dataset/sg_test_images/5242879582_06afc5beb6_b.jpg
#   inflating: sg_dataset/sg_test_images/5243039066_239be0fbb6_b.jpg
#   inflating: sg_dataset/sg_test_images/5255039125_97c40ac60a_b.jpg
#   inflating: sg_dataset/sg_test_images/5268687055_77c3c5f405_b.jpg
#   inflating: sg_dataset/sg_test_images/528521681_815e86d758_b.jpg
#   inflating: sg_dataset/sg_test_images/5297711298_16cf54cc96_b.jpg
#   inflating: sg_dataset/sg_test_images/5307224072_996eca4f12_b.jpg
#   inflating: sg_dataset/sg_test_images/5313611179_92c5f62da6_b.jpg
#   inflating: sg_dataset/sg_test_images/5315650616_a1e4d88121_b.jpg
#   inflating: sg_dataset/sg_test_images/5326233477_c61f9f0155_b.jpg
#   inflating: sg_dataset/sg_test_images/533758830_488c7e9730_o.jpg
#   inflating: sg_dataset/sg_test_images/533864567_b70c6aa4ca_o.jpg
#   inflating: sg_dataset/sg_test_images/5347302149_42884497b0_b.jpg
#   inflating: sg_dataset/sg_test_images/534826000_d2ca6f50ee_o.jpg
#   inflating: sg_dataset/sg_test_images/5352517718_a3c849a03e_b.jpg
#   inflating: sg_dataset/sg_test_images/5359060618_bf626eda51_b.jpg
#   inflating: sg_dataset/sg_test_images/536158324_77c119d759_b.jpg
#   inflating: sg_dataset/sg_test_images/53674969_7b9ab949ad_o.jpg
#   inflating: sg_dataset/sg_test_images/5378594477_31245a0dc1_b.jpg
#   inflating: sg_dataset/sg_test_images/5384700864_fd67612121_b.jpg
#   inflating: sg_dataset/sg_test_images/5387078872_fc853f9179_b.jpg
#   inflating: sg_dataset/sg_test_images/5388505432_fc3e1b20db_b.jpg
#   inflating: sg_dataset/sg_test_images/5390999080_7d993b0bc3_b.jpg
#   inflating: sg_dataset/sg_test_images/54015226_01c69ff57f_b.jpg
#   inflating: sg_dataset/sg_test_images/5406472568_78d687217f_b.jpg
#   inflating: sg_dataset/sg_test_images/5418301101_63043414ea_b.jpg
#   inflating: sg_dataset/sg_test_images/5418800627_063517c1f2_b.jpg
#   inflating: sg_dataset/sg_test_images/5428161470_e612cbe805_b.jpg
#   inflating: sg_dataset/sg_test_images/5430547851_af4dd1a9a7_b.jpg
#   inflating: sg_dataset/sg_test_images/5434642006_4a0be04843_b.jpg
#   inflating: sg_dataset/sg_test_images/5438088932_a580bb3bc3_b.jpg
#   inflating: sg_dataset/sg_test_images/5452090847_a9ba3925e5_b.jpg
#   inflating: sg_dataset/sg_test_images/5453019457_2c3303007a_b.jpg
#   inflating: sg_dataset/sg_test_images/5462071595_6f6befe7a5_b.jpg
#   inflating: sg_dataset/sg_test_images/5465443054_1def817670_b.jpg
#   inflating: sg_dataset/sg_test_images/5471365300_ac5b8723bf_b.jpg
#   inflating: sg_dataset/sg_test_images/5473072314_d0aeb2ed2a_b.jpg
#   inflating: sg_dataset/sg_test_images/5490544411_8d482e0730_b.jpg
#   inflating: sg_dataset/sg_test_images/5491741916_9e11e8ef2c_b.jpg
#   inflating: sg_dataset/sg_test_images/549562103_e5f391c8d7_b.jpg
#   inflating: sg_dataset/sg_test_images/5505671085_be11bafb7e_b.jpg
#   inflating: sg_dataset/sg_test_images/5524913075_94e0bdf94c_b.jpg
#   inflating: sg_dataset/sg_test_images/5531467160_2ae2cb76d4_b.jpg
#   inflating: sg_dataset/sg_test_images/5557032034_d167d65920_b.jpg
#   inflating: sg_dataset/sg_test_images/5564918619_bdb87d2833_b.jpg
#   inflating: sg_dataset/sg_test_images/5566670319_0bb3ee5999_b.jpg
#   inflating: sg_dataset/sg_test_images/5568917201_aacb67230a_b.jpg
#   inflating: sg_dataset/sg_test_images/5570540658_c010a58d2a_b.jpg
#   inflating: sg_dataset/sg_test_images/5574065753_30f64d597e_b.jpg
#   inflating: sg_dataset/sg_test_images/5586675408_771fb66f70_b.jpg
#   inflating: sg_dataset/sg_test_images/55882023_3791f9e1f9_b.jpg
#   inflating: sg_dataset/sg_test_images/5589907565_54b7820e7d_b.jpg
#   inflating: sg_dataset/sg_test_images/5600472556_40b4f90b91_b.jpg
#   inflating: sg_dataset/sg_test_images/5602631097_4c23f9fe14_b.jpg
#   inflating: sg_dataset/sg_test_images/561071079_5f5435778e_b.jpg
#   inflating: sg_dataset/sg_test_images/5611889975_8af5fd76b5_b.jpg
#   inflating: sg_dataset/sg_test_images/5615329604_4e715d25db_b.jpg
#   inflating: sg_dataset/sg_test_images/5616987281_dc42cdee74_b.jpg
#   inflating: sg_dataset/sg_test_images/5619918180_0b11e6a97d_b.jpg
#   inflating: sg_dataset/sg_test_images/5642613046_67f639741c_b.jpg
#   inflating: sg_dataset/sg_test_images/564692105_8ad48ea492_b.jpg
#   inflating: sg_dataset/sg_test_images/5651734309_4667d9abb4_b.jpg
#   inflating: sg_dataset/sg_test_images/5652833786_ef7dddfb21_b.jpg
#   inflating: sg_dataset/sg_test_images/5660988052_20249b631c_b.jpg
#   inflating: sg_dataset/sg_test_images/5663152990_60111361e0_b.jpg
#   inflating: sg_dataset/sg_test_images/5678299761_13f9429f1f_b.jpg
#   inflating: sg_dataset/sg_test_images/5680794405_4fc2ce1fc8_b.jpg
#   inflating: sg_dataset/sg_test_images/5683037151_6679dfe9ae_b.jpg
#   inflating: sg_dataset/sg_test_images/5684583759_38b776f49f_b.jpg
#   inflating: sg_dataset/sg_test_images/5691605489_f37720bca0_b.jpg
#   inflating: sg_dataset/sg_test_images/5695527828_50d0b012cb_b.jpg
#   inflating: sg_dataset/sg_test_images/5705736136_1d0b311c76_b.jpg
#   inflating: sg_dataset/sg_test_images/5715148858_a39a0e7a2a_b.jpg
#   inflating: sg_dataset/sg_test_images/5717492963_acc6ca4b5e_b.jpg
#   inflating: sg_dataset/sg_test_images/572129903_d7c9256759_o.jpg
#   inflating: sg_dataset/sg_test_images/5730484786_3088a25aa5_b.jpg
#   inflating: sg_dataset/sg_test_images/5744483171_5a79828274_b.jpg
#   inflating: sg_dataset/sg_test_images/5748550971_3134942403_b.jpg
#   inflating: sg_dataset/sg_test_images/5758673398_660840e2f6_b.jpg
#   inflating: sg_dataset/sg_test_images/5775635875_1d01bded57_b.jpg
#   inflating: sg_dataset/sg_test_images/5801858089_4fc1ed6b44_b.jpg
#   inflating: sg_dataset/sg_test_images/5802393207_fa134b8756_b.jpg
#   inflating: sg_dataset/sg_test_images/5813825129_8220867fa9_b.jpg
#   inflating: sg_dataset/sg_test_images/5816208499_9c5eeb21f6_b.jpg
#   inflating: sg_dataset/sg_test_images/5816665318_4f92c28721_b.jpg
#   inflating: sg_dataset/sg_test_images/5825054975_93a8e9298b_b.jpg
#   inflating: sg_dataset/sg_test_images/5829524547_c86197d694_b.jpg
#   inflating: sg_dataset/sg_test_images/5830707189_2b7d70c3f5_b.jpg
#   inflating: sg_dataset/sg_test_images/5843016079_70bc3982a9_b.jpg
#   inflating: sg_dataset/sg_test_images/5863952199_6fcc86e248_b.jpg
#   inflating: sg_dataset/sg_test_images/5866509996_1c95a5c376_b.jpg
#   inflating: sg_dataset/sg_test_images/5870797431_00a5f8a60d_b.jpg
#   inflating: sg_dataset/sg_test_images/5875410575_17c6729e50_b.jpg
#   inflating: sg_dataset/sg_test_images/5877816539_b7a25abdde_b.jpg
#   inflating: sg_dataset/sg_test_images/5884024667_5bc652bed5_b.jpg
#   inflating: sg_dataset/sg_test_images/5888340022_0af85c1d9a_b.jpg
#   inflating: sg_dataset/sg_test_images/5896543857_72d70826ab_b.jpg
#   inflating: sg_dataset/sg_test_images/5913010462_baefe1204d_b.jpg
#   inflating: sg_dataset/sg_test_images/5932612176_1df75f5d49_b.jpg
#   inflating: sg_dataset/sg_test_images/5936943675_d0ac9b3978_o.jpg
#   inflating: sg_dataset/sg_test_images/5938767806_2ba0035f56_o.jpg
#   inflating: sg_dataset/sg_test_images/5941494725_1126ae5203_b.jpg
#   inflating: sg_dataset/sg_test_images/5942883987_2eab794bc6_b.jpg
#   inflating: sg_dataset/sg_test_images/5946908528_dc6407edfe_b.jpg
#   inflating: sg_dataset/sg_test_images/5951879617_bd7b1cd183_b.jpg
#   inflating: sg_dataset/sg_test_images/5953228514_f60f6fa420_b.jpg
#   inflating: sg_dataset/sg_test_images/5954064332_4786c70125_b.jpg
#   inflating: sg_dataset/sg_test_images/5972285362_4bf7f957a2_b.jpg
#   inflating: sg_dataset/sg_test_images/5976803772_3345fe000f_b.jpg
#   inflating: sg_dataset/sg_test_images/5977164804_b23c552d48_b.jpg
#   inflating: sg_dataset/sg_test_images/5983169504_796734fb80_b.jpg
#   inflating: sg_dataset/sg_test_images/5986618302_af8bce885a_b.jpg
#   inflating: sg_dataset/sg_test_images/5993603031_17dd8d9705_b.jpg
#   inflating: sg_dataset/sg_test_images/5995908548_6684882acd_b.jpg
#   inflating: sg_dataset/sg_test_images/6000568061_0e26598db9_b.jpg
#   inflating: sg_dataset/sg_test_images/6045928403_7d0084e6a3_b.jpg
#   inflating: sg_dataset/sg_test_images/6049867763_c04a10071f_b.jpg
#   inflating: sg_dataset/sg_test_images/6051641977_c379e70ba5_b.jpg
#   inflating: sg_dataset/sg_test_images/6055000972_6443b170a9_b.jpg
#   inflating: sg_dataset/sg_test_images/6056241856_8a11e30ea9_b.jpg
#   inflating: sg_dataset/sg_test_images/6069328607_f4169d249b_b.jpg
#   inflating: sg_dataset/sg_test_images/60733093_2c84ce06f9_o.jpg
#   inflating: sg_dataset/sg_test_images/6082726280_2592fc2929_b.jpg
#   inflating: sg_dataset/sg_test_images/6092596567_23cabf8a62_b.jpg
#   inflating: sg_dataset/sg_test_images/6093897610_9cd5e8b05a_b.jpg
#   inflating: sg_dataset/sg_test_images/6105556802_6e01d10541_b.jpg
#   inflating: sg_dataset/sg_test_images/6108452563_938df41c42_b.jpg
#   inflating: sg_dataset/sg_test_images/6117976473_de7b0622b7_b.jpg
#   inflating: sg_dataset/sg_test_images/6131089361_5a48c553fd_b.jpg
#   inflating: sg_dataset/sg_test_images/6161159178_8fa749a7b7_b.jpg
#   inflating: sg_dataset/sg_test_images/6190175633_489f3d7536_b.jpg
#   inflating: sg_dataset/sg_test_images/6206106665_4baf156e08_b.jpg
#   inflating: sg_dataset/sg_test_images/6208394976_47facaa7ef_b.jpg
#   inflating: sg_dataset/sg_test_images/6215579954_c016735332_b.jpg
#   inflating: sg_dataset/sg_test_images/6216901971_786976ff66_b.jpg
#   inflating: sg_dataset/sg_test_images/6227973374_e69b2be679_b.jpg
#   inflating: sg_dataset/sg_test_images/6232252278_c815ffa0a4_b.jpg
#   inflating: sg_dataset/sg_test_images/6243106760_1ba006752b_b.jpg
#   inflating: sg_dataset/sg_test_images/6244564065_c5247575c0_b.jpg
#   inflating: sg_dataset/sg_test_images/6245496268_9b9e43ba84_b.jpg
#   inflating: sg_dataset/sg_test_images/6246451356_810fa8f8f3_b.jpg
#   inflating: sg_dataset/sg_test_images/6260429135_d65d4e6726_b.jpg
#   inflating: sg_dataset/sg_test_images/6279585054_1f9d450f35_b.jpg
#   inflating: sg_dataset/sg_test_images/6284525689_7b1309b25a_b.jpg
#   inflating: sg_dataset/sg_test_images/6296054082_618236d880_b.jpg
#   inflating: sg_dataset/sg_test_images/6315596287_a690deabd9_b.jpg
#   inflating: sg_dataset/sg_test_images/6317559515_1235fb0c25_b.jpg
#   inflating: sg_dataset/sg_test_images/6318833559_597c34646e_b.jpg
#   inflating: sg_dataset/sg_test_images/6325517947_16006e0f7d_b.jpg
#   inflating: sg_dataset/sg_test_images/6343384971_26432f428f_b.jpg
#   inflating: sg_dataset/sg_test_images/6343984716_425239576b_b.jpg
#   inflating: sg_dataset/sg_test_images/6365235685_7fa14dbb6e_b.jpg
#   inflating: sg_dataset/sg_test_images/6374376091_3e2f6a06de_b.jpg
#   inflating: sg_dataset/sg_test_images/6374812041_0af1a67647_b.jpg
#   inflating: sg_dataset/sg_test_images/6378957229_e8190db64a_b.jpg
#   inflating: sg_dataset/sg_test_images/6425960875_b3e545f2b6_b.jpg
#   inflating: sg_dataset/sg_test_images/6434621213_a3562bf97d_b.jpg
#   inflating: sg_dataset/sg_test_images/6442967833_fba9355477_b.jpg
#   inflating: sg_dataset/sg_test_images/6463419153_6eeb8969f2_b.jpg
#   inflating: sg_dataset/sg_test_images/649656486_40fd09aac2_b.jpg
#   inflating: sg_dataset/sg_test_images/6514046205_9a44d63a8c_b.jpg
#   inflating: sg_dataset/sg_test_images/6515786451_3126c0c6f8_b.jpg
#   inflating: sg_dataset/sg_test_images/6518404431_46c1f5be52_b.jpg
#   inflating: sg_dataset/sg_test_images/6549487471_bf8a5b4b5f_b.jpg
#   inflating: sg_dataset/sg_test_images/6555965521_d28e8e3e8a_b.jpg
#   inflating: sg_dataset/sg_test_images/6576479141_50d5cf0e26_b.jpg
#   inflating: sg_dataset/sg_test_images/6583647513_eed45a37d8_b.jpg
#   inflating: sg_dataset/sg_test_images/6604207041_3a075b031d_b.jpg
#   inflating: sg_dataset/sg_test_images/6615239251_f0d7bc616b_b.jpg
#   inflating: sg_dataset/sg_test_images/6635859965_e72c387cd7_b.jpg
#   inflating: sg_dataset/sg_test_images/6653105297_3557d439bf_b.jpg
#   inflating: sg_dataset/sg_test_images/6705389705_78dcbcd6b2_b.jpg
#   inflating: sg_dataset/sg_test_images/6707729613_ca7004ca68_b.jpg
#   inflating: sg_dataset/sg_test_images/6740202035_2e223eef78_b.jpg
#   inflating: sg_dataset/sg_test_images/674465845_c39463fad7_b.jpg
#   inflating: sg_dataset/sg_test_images/6760111765_020473fef8_b.jpg
#   inflating: sg_dataset/sg_test_images/6766399563_3348857c51_b.jpg
#   inflating: sg_dataset/sg_test_images/6778132399_93caa7680d_b.jpg
#   inflating: sg_dataset/sg_test_images/6779312189_ba4bfa17a0_o.jpg
#   inflating: sg_dataset/sg_test_images/6780133983_12c71db6e0_b.jpg
#   inflating: sg_dataset/sg_test_images/6793856865_50959f216a_b.jpg
#   inflating: sg_dataset/sg_test_images/6815047926_893a3e9c3f_b.jpg
#   inflating: sg_dataset/sg_test_images/6820244984_933c261abd_b.jpg
#   inflating: sg_dataset/sg_test_images/6824201485_dd143cffe2_b.jpg
#   inflating: sg_dataset/sg_test_images/6827397981_666f72d7e5_b.jpg
#   inflating: sg_dataset/sg_test_images/6833191949_3ff60dce43_b.jpg
#   inflating: sg_dataset/sg_test_images/6834952690_740e6ea3f8_b.jpg
#   inflating: sg_dataset/sg_test_images/6851206016_fc7a0bdebc_b.jpg
#   inflating: sg_dataset/sg_test_images/6859695802_f584e9ee97_b.jpg
#   inflating: sg_dataset/sg_test_images/6866914249_e7af747aec_b.jpg
#   inflating: sg_dataset/sg_test_images/6872898747_c7b540e84c_b.jpg
#   inflating: sg_dataset/sg_test_images/6904597525_d008ab6805_b.jpg
#   inflating: sg_dataset/sg_test_images/6908857266_4792c724e0_b.jpg
#   inflating: sg_dataset/sg_test_images/6912507028_ae2c6aa4d5_b.jpg
#   inflating: sg_dataset/sg_test_images/6917705703_fb8151a7e7_b.jpg
#   inflating: sg_dataset/sg_test_images/6921255501_a627ec447f_b.jpg
#   inflating: sg_dataset/sg_test_images/6921396529_aedcda6031_b.jpg
#   inflating: sg_dataset/sg_test_images/6924739682_e0943b021c_b.jpg
#   inflating: sg_dataset/sg_test_images/6930980950_797f2c4b9f_b.jpg
#   inflating: sg_dataset/sg_test_images/6937748857_768c7dca10_b.jpg
#   inflating: sg_dataset/sg_test_images/6942184666_8aca21df78_b.jpg
#   inflating: sg_dataset/sg_test_images/6950750604_ed66a64e7c_b.jpg
#   inflating: sg_dataset/sg_test_images/6957336027_c245f95dc1_b.jpg
#   inflating: sg_dataset/sg_test_images/6976146955_4a039fc17e_b.jpg
#   inflating: sg_dataset/sg_test_images/6977677651_b71e9afbe1_b.jpg
#   inflating: sg_dataset/sg_test_images/6981427494_28e826175d_b.jpg
#   inflating: sg_dataset/sg_test_images/6989051067_ed029c7c61_b.jpg
#   inflating: sg_dataset/sg_test_images/7035289001_c2afff1d55_b.jpg
#   inflating: sg_dataset/sg_test_images/7040353469_ed8390cd93_b.jpg
#   inflating: sg_dataset/sg_test_images/7048797857_74b0bae368_b.jpg
#   inflating: sg_dataset/sg_test_images/7071657405_fc469c78ea_b.jpg
#   inflating: sg_dataset/sg_test_images/7091065905_f8f52946da_b.jpg
#   inflating: sg_dataset/sg_test_images/7094510591_d15efa34aa_b.jpg
#   inflating: sg_dataset/sg_test_images/7139423751_5452ba19cd_b.jpg
#   inflating: sg_dataset/sg_test_images/7168869419_2b523a5033_b.jpg
#   inflating: sg_dataset/sg_test_images/7170014597_1a8dff9d7b_b.jpg
#   inflating: sg_dataset/sg_test_images/7184186830_827eda97cb_b.jpg
#   inflating: sg_dataset/sg_test_images/7198871910_da7f41ca9f_b.jpg
#   inflating: sg_dataset/sg_test_images/7205963930_cea220ba20_b.jpg
#   inflating: sg_dataset/sg_test_images/7239473768_05739a5b96_b.jpg
#   inflating: sg_dataset/sg_test_images/7254840318_62657d3bbe_b.jpg
#   inflating: sg_dataset/sg_test_images/7264097440_609d106ee1_b.jpg
#   inflating: sg_dataset/sg_test_images/7277852436_1f48c990d2_b.jpg
#   inflating: sg_dataset/sg_test_images/7300781238_d409502492_b.jpg
#   inflating: sg_dataset/sg_test_images/7303187476_294fa66cf5_b.jpg
#   inflating: sg_dataset/sg_test_images/7315412790_53e93071c9_b.jpg
#   inflating: sg_dataset/sg_test_images/73325313_7e3d8f6ccc_o.jpg
#   inflating: sg_dataset/sg_test_images/7348234584_c58df88db5_b.jpg
#   inflating: sg_dataset/sg_test_images/7355366602_5dd0675407_b.jpg
#   inflating: sg_dataset/sg_test_images/7361214092_ed11d3505f_b.jpg
#   inflating: sg_dataset/sg_test_images/7365866590_9ee29c7f2e_b.jpg
#   inflating: sg_dataset/sg_test_images/7366789750_a206640468_b.jpg
#   inflating: sg_dataset/sg_test_images/7369137456_4b37f4e324_b.jpg
#   inflating: sg_dataset/sg_test_images/7370871500_a5790701c0_b.jpg
#   inflating: sg_dataset/sg_test_images/7400954768_a9b38d7673_b.jpg
#   inflating: sg_dataset/sg_test_images/7401056888_55e8cdea5c_b.jpg
#   inflating: sg_dataset/sg_test_images/7405095362_98c129d679_b.jpg
#   inflating: sg_dataset/sg_test_images/7417695040_ef9d321658_b.jpg
#   inflating: sg_dataset/sg_test_images/7433561234_012196febd_b.jpg
#   inflating: sg_dataset/sg_test_images/7433898796_663bc86e52_b.jpg
#   inflating: sg_dataset/sg_test_images/7441526440_0a8118937e_b.jpg
#   inflating: sg_dataset/sg_test_images/7444968726_d9e046d616_b.jpg
#   inflating: sg_dataset/sg_test_images/7469804332_e138ab6d9a_b.jpg
#   inflating: sg_dataset/sg_test_images/7473102164_24c8e3d030_b.jpg
#   inflating: sg_dataset/sg_test_images/7479763654_c6fec5d93f_b.jpg
#   inflating: sg_dataset/sg_test_images/7503712440_d88421f5db_b.jpg
#   inflating: sg_dataset/sg_test_images/7513920660_e1b9f2202d_b.jpg
#   inflating: sg_dataset/sg_test_images/7517053772_f81ba00b2a_b.jpg
#   inflating: sg_dataset/sg_test_images/7524287460_ebe216aa33_b.jpg
#   inflating: sg_dataset/sg_test_images/7536670772_4e259caf25_o.jpg
#   inflating: sg_dataset/sg_test_images/7545830044_d84ac9d4a4_o.jpg
#   inflating: sg_dataset/sg_test_images/757264230_39cab782b6_b.jpg
#   inflating: sg_dataset/sg_test_images/7574977682_b8819ffe13_b.jpg
#   inflating: sg_dataset/sg_test_images/7577204808_3c75f97ced_b.jpg
#   inflating: sg_dataset/sg_test_images/7594046316_0a92d8c9cd_b.jpg
#   inflating: sg_dataset/sg_test_images/7611410004_dcd54d8cfe_b.jpg
# ...
#   inflating: sg_dataset/sg_train_images/9404504695_f63fef1670_b.jpg
#   inflating: sg_dataset/sg_train_images/9405472443_0eb737abb6_b.jpg
#   inflating: sg_dataset/sg_train_images/9407860848_b2fceff7df_b.jpg
#   inflating: sg_dataset/sg_train_images/9408224451_0254d56cd1_b.jpg
#   inflating: sg_dataset/sg_train_images/9413317849_59ee037005_b.jpg
#   inflating: sg_dataset/sg_train_images/9413812676_a0836137d8_b.jpg
#   inflating: sg_dataset/sg_train_images/9414483501_ff59654a0f_b.jpg
#   inflating: sg_dataset/sg_train_images/9414636394_0ae3c0951c_b.jpg
#   inflating: sg_dataset/sg_train_images/9414988919_1ae1612288_o.jpg
#   inflating: sg_dataset/sg_train_images/9416151887_9ec7680564_b.jpg
#   inflating: sg_dataset/sg_train_images/9420171433_0c28ed5369_b.jpg
#   inflating: sg_dataset/sg_train_images/9421179933_1b652d6e78_b.jpg
#   inflating: sg_dataset/sg_train_images/9421963813_ff2c7f6145_b.jpg
#   inflating: sg_dataset/sg_train_images/9425058051_d588dca90a_o.jpg
#   inflating: sg_dataset/sg_train_images/9426001839_093644f906_b.jpg
#   inflating: sg_dataset/sg_train_images/9426740552_fe479a063e_b.jpg
#   inflating: sg_dataset/sg_train_images/9427606795_c715bf4c11_b.jpg
#   inflating: sg_dataset/sg_train_images/94288580_29b1cedd2f_b.jpg
#   inflating: sg_dataset/sg_train_images/9430680992_7ced2eafbd_b.jpg
#   inflating: sg_dataset/sg_train_images/9434047748_22ab7471ec_b.jpg
#   inflating: sg_dataset/sg_train_images/9434142535_cae73ebed4_b.jpg
#   inflating: sg_dataset/sg_train_images/9438045523_2e832236ab_b.jpg
#   inflating: sg_dataset/sg_train_images/9439527323_efcf837a5d_b.jpg
#   inflating: sg_dataset/sg_train_images/9439835154_0e359c8d5b_b.jpg
#   inflating: sg_dataset/sg_train_images/9449145978_f5715dcdb3_b.jpg
#   inflating: sg_dataset/sg_train_images/9449747294_08bd4750a0_b.jpg
#   inflating: sg_dataset/sg_train_images/9454509787_20ac37cc6e_b.jpg
#   inflating: sg_dataset/sg_train_images/9456571860_4b33edd63b_b.jpg
#   inflating: sg_dataset/sg_train_images/9461640166_192dbb5562_b.jpg
#   inflating: sg_dataset/sg_train_images/9465172557_3f5ac3e1a0_b.jpg
#   inflating: sg_dataset/sg_train_images/9469066386_71f6393eb1_b.jpg
#   inflating: sg_dataset/sg_train_images/9469366873_af3accdd76_b.jpg
#   inflating: sg_dataset/sg_train_images/9470067708_809b07a162_b.jpg
#   inflating: sg_dataset/sg_train_images/947317936_6816fc0426_o.jpg
#   inflating: sg_dataset/sg_train_images/9474210296_d5de954af8_b.jpg
#   inflating: sg_dataset/sg_train_images/9479194189_c8e3800ffd_b.jpg
#   inflating: sg_dataset/sg_train_images/9482051038_a6b691c0d5_b.jpg
#   inflating: sg_dataset/sg_train_images/9484373860_d0043d6e67_b.jpg
#   inflating: sg_dataset/sg_train_images/9485679704_bc2525c8c8_b.jpg
#   inflating: sg_dataset/sg_train_images/9485870763_8d530760b9_b.jpg
#   inflating: sg_dataset/sg_train_images/9486283424_3ba368b294_b.jpg
#   inflating: sg_dataset/sg_train_images/9486715195_681f34a6b9_b.jpg
#   inflating: sg_dataset/sg_train_images/9487308436_241f0a4a3f_b.jpg
#   inflating: sg_dataset/sg_train_images/94889859_38289e9d5c_o.jpg
#   inflating: sg_dataset/sg_train_images/9489706788_6fc9a35bd4_b.jpg
#   inflating: sg_dataset/sg_train_images/9491864615_68ea361426_b.jpg
#   inflating: sg_dataset/sg_train_images/9496685848_3cde6618fb_b.jpg
#   inflating: sg_dataset/sg_train_images/9497438546_c33b3d32a9_b.jpg
#   inflating: sg_dataset/sg_train_images/9502991381_52cd6614f1_b.jpg
#   inflating: sg_dataset/sg_train_images/9507041847_55150ac06d_b.jpg
#   inflating: sg_dataset/sg_train_images/9507847595_5079520cf9_o.jpg
#   inflating: sg_dataset/sg_train_images/9509723663_b3b8a0f3be_b.jpg
#   inflating: sg_dataset/sg_train_images/9509838518_60514f6c6e_b.jpg
#   inflating: sg_dataset/sg_train_images/9513108792_69098a1941_b.jpg
#   inflating: sg_dataset/sg_train_images/9514068596_48a19398c4_b.jpg
#   inflating: sg_dataset/sg_train_images/9515748684_69eb6e9c36_b.jpg
#   inflating: sg_dataset/sg_train_images/9517003813_26097ecc7e_b.jpg
#   inflating: sg_dataset/sg_train_images/9517130341_84bc38707b_b.jpg
#   inflating: sg_dataset/sg_train_images/9517870987_82258def0f_b.jpg
#   inflating: sg_dataset/sg_train_images/9518591200_44a9d4b920_o.jpg
#   inflating: sg_dataset/sg_train_images/9520141788_b793ffe6b8_b.jpg
#   inflating: sg_dataset/sg_train_images/9523928163_c3ef5bcb75_o.jpg
#   inflating: sg_dataset/sg_train_images/9527663616_abf9b15054_b.jpg
#   inflating: sg_dataset/sg_train_images/9528569902_e8b3e09802_b.jpg
#   inflating: sg_dataset/sg_train_images/9529014465_cedd06f60a_b.jpg
#   inflating: sg_dataset/sg_train_images/9529946680_ed124d4dd6_b.jpg
#   inflating: sg_dataset/sg_train_images/9530557095_b257fa00a0_b.jpg
#   inflating: sg_dataset/sg_train_images/9533523324_2f98357d2f_b.jpg
#   inflating: sg_dataset/sg_train_images/9534513677_cb3b6eed7e_b.jpg
#   inflating: sg_dataset/sg_train_images/9535038973_2ae04391d1_b.jpg
#   inflating: sg_dataset/sg_train_images/9535192327_66cd4ecc0c_b.jpg
#   inflating: sg_dataset/sg_train_images/9536590087_96f659fb59_b.jpg
#   inflating: sg_dataset/sg_train_images/9537388729_5cdca49e77_b.jpg
#   inflating: sg_dataset/sg_train_images/9537653771_d0068b0b78_b.jpg
#   inflating: sg_dataset/sg_train_images/9538952662_f7ff9b1461_b.jpg
#   inflating: sg_dataset/sg_train_images/9539615951_61889dd25c_o.jpg
#   inflating: sg_dataset/sg_train_images/9541602233_c3dbdd9f4a_b.jpg
#   inflating: sg_dataset/sg_train_images/9544061327_f675900fa2_b.jpg
#   inflating: sg_dataset/sg_train_images/9544233945_70e241919e_b.jpg
#   inflating: sg_dataset/sg_train_images/9544408990_0751a672ab_b.jpg
#   inflating: sg_dataset/sg_train_images/9544656336_1143c3ebc9_b.jpg
#   inflating: sg_dataset/sg_train_images/9546659710_ba71bea338_b.jpg
#   inflating: sg_dataset/sg_train_images/9546689312_b652f55003_b.jpg
#   inflating: sg_dataset/sg_train_images/9548187683_9e025e1ea4_b.jpg
#   inflating: sg_dataset/sg_train_images/9550217831_683462f6de_b.jpg
#   inflating: sg_dataset/sg_train_images/9552615557_c3d9b9b574_b.jpg
#   inflating: sg_dataset/sg_train_images/9553510705_ee9155a2dd_b.jpg
#   inflating: sg_dataset/sg_train_images/9554427249_919da513fa_b.jpg
#   inflating: sg_dataset/sg_train_images/9556100464_d26486b206_b.jpg
#   inflating: sg_dataset/sg_train_images/9556656690_76f6711070_b.jpg
#   inflating: sg_dataset/sg_train_images/9556929741_31d043fb98_b.jpg
#   inflating: sg_dataset/sg_train_images/9558147346_9a4cbd84d5_b.jpg
#   inflating: sg_dataset/sg_train_images/9558456557_6b275f3efc_b.jpg
#   inflating: sg_dataset/sg_train_images/9561419764_c12dc30e76_b.jpg
#   inflating: sg_dataset/sg_train_images/9565361170_d54f928d9a_o.jpg
#   inflating: sg_dataset/sg_train_images/9567750328_da390a0c52_b.jpg
#   inflating: sg_dataset/sg_train_images/9568594161_9f56f565d2_o.jpg
#   inflating: sg_dataset/sg_train_images/9569516417_ea42b380b3_b.jpg
#   inflating: sg_dataset/sg_train_images/9570708801_921e9ab7c2_b.jpg
#   inflating: sg_dataset/sg_train_images/9572109341_c724ef7ba7_b.jpg
#   inflating: sg_dataset/sg_train_images/95723848_6371b5123a_o.jpg
#   inflating: sg_dataset/sg_train_images/9575927098_ddc47eea23_b.jpg
#   inflating: sg_dataset/sg_train_images/9579613756_3a7d99a6f5_b.jpg
#   inflating: sg_dataset/sg_train_images/9581569794_d0fb3d7956_b.jpg
#   inflating: sg_dataset/sg_train_images/9587167369_6226d0c4f3_b.jpg
#   inflating: sg_dataset/sg_train_images/9589151115_5db3d225ae_b.jpg
#   inflating: sg_dataset/sg_train_images/9592354594_f4119c9f5b_o.jpg
#   inflating: sg_dataset/sg_train_images/9595192889_f25d37597f_b.jpg
#   inflating: sg_dataset/sg_train_images/9598312981_0af6aaf49c_b.jpg
#   inflating: sg_dataset/sg_train_images/9598935633_5e285cec4e_b.jpg
#   inflating: sg_dataset/sg_train_images/9601384300_5cb8b2bd90_b.jpg
#   inflating: sg_dataset/sg_train_images/9602004447_0d20a9bf70_b.jpg
#   inflating: sg_dataset/sg_train_images/9604033757_c21f78484e_b.jpg
#   inflating: sg_dataset/sg_train_images/9604123061_293eb383dc_b.jpg
#   inflating: sg_dataset/sg_train_images/9609672745_21964c3aa6_b.jpg
#   inflating: sg_dataset/sg_train_images/9612276764_253ca7b6ba_o.jpg
#   inflating: sg_dataset/sg_train_images/9613465289_ca0698d55c_b.jpg
#   inflating: sg_dataset/sg_train_images/9618626250_0da296d0cc_b.jpg
#   inflating: sg_dataset/sg_train_images/9619130106_c27b3b7323_b.jpg
#   inflating: sg_dataset/sg_train_images/9633163875_15c2967389_b.jpg
#   inflating: sg_dataset/sg_train_images/9633620305_142b8ea744_b.jpg
#   inflating: sg_dataset/sg_train_images/9633627157_30756cb0e1_b.jpg
#   inflating: sg_dataset/sg_train_images/9635094157_5274745b53_b.jpg
#   inflating: sg_dataset/sg_train_images/9636666194_484da07806_b.jpg
#   inflating: sg_dataset/sg_train_images/9637594607_4a315f5084_b.jpg
#   inflating: sg_dataset/sg_train_images/9639102351_92be46f111_b.jpg
#   inflating: sg_dataset/sg_train_images/9639139133_3220181cab_b.jpg
#   inflating: sg_dataset/sg_train_images/9641306920_f1444f5952_b.jpg
#   inflating: sg_dataset/sg_train_images/9647798837_4940c7c86c_b.jpg
#   inflating: sg_dataset/sg_train_images/9653331120_aa44db4e9d_b.jpg
#   inflating: sg_dataset/sg_train_images/9653931989_4cc05560e3_b.jpg
#   inflating: sg_dataset/sg_train_images/9656069709_9b63c861b5_b.jpg
#   inflating: sg_dataset/sg_train_images/9656117187_5c8cd18b14_b.jpg
#   inflating: sg_dataset/sg_train_images/9657117092_5d11e096a2_b.jpg
#   inflating: sg_dataset/sg_train_images/9657253006_b038a55ab7_b.jpg
#   inflating: sg_dataset/sg_train_images/9659054273_423b8fbdb9_b.jpg
#   inflating: sg_dataset/sg_train_images/9659238693_0c0331f02c_b.jpg
#   inflating: sg_dataset/sg_train_images/9661679965_b31595c743_b.jpg
#   inflating: sg_dataset/sg_train_images/9664305296_1f2ce5db37_o.jpg
#   inflating: sg_dataset/sg_train_images/9665338198_f5a61d0b85_b.jpg
#   inflating: sg_dataset/sg_train_images/9670359088_96348cc07c_b.jpg
#   inflating: sg_dataset/sg_train_images/9674036897_48507e216b_b.jpg
#   inflating: sg_dataset/sg_train_images/9676606537_6c98c38bcf_b.jpg
#   inflating: sg_dataset/sg_train_images/9677515089_b77141d2e7_b.jpg
#   inflating: sg_dataset/sg_train_images/9677717021_9149b7e10e_b.jpg
#   inflating: sg_dataset/sg_train_images/9679337943_e8912aaff6_b.jpg
#   inflating: sg_dataset/sg_train_images/9682506274_39645acc03_b.jpg
#   inflating: sg_dataset/sg_train_images/9682571385_ef60347fe9_b.jpg
#   inflating: sg_dataset/sg_train_images/9684356579_883c8f4e4b_b.jpg
#   inflating: sg_dataset/sg_train_images/9689292609_b0bf279553_b.jpg
#   inflating: sg_dataset/sg_train_images/9689719237_c619e12bc6_b.jpg
#   inflating: sg_dataset/sg_train_images/9691713623_df67749691_b.jpg
#   inflating: sg_dataset/sg_train_images/9692252030_f1db6b57d9_o.jpg
#   inflating: sg_dataset/sg_train_images/9692771432_7e9ba08cec_b.jpg
#   inflating: sg_dataset/sg_train_images/9694542596_5c7de71d0d_o.jpg
#   inflating: sg_dataset/sg_train_images/9694927378_f1a3d22393_b.jpg
#   inflating: sg_dataset/sg_train_images/9694940064_4b704c4423_b.jpg
#   inflating: sg_dataset/sg_train_images/96962166_b98a28206a_o.jpg
#   inflating: sg_dataset/sg_train_images/9696223786_22536b848c_b.jpg
#   inflating: sg_dataset/sg_train_images/97000333_9c6b968a17_o.jpg
#   inflating: sg_dataset/sg_train_images/9701240505_e8610bac3d_b.jpg
#   inflating: sg_dataset/sg_train_images/9703241066_9b5e9b290e_b.jpg
#   inflating: sg_dataset/sg_train_images/9704810682_804eaa1fd1_b.jpg
#   inflating: sg_dataset/sg_train_images/9718713401_d52b795a1b_b.jpg
#   inflating: sg_dataset/sg_train_images/9719081589_80dda07912_b.jpg
#   inflating: sg_dataset/sg_train_images/9719725824_1cdc812cc1_b.jpg
#   inflating: sg_dataset/sg_train_images/972396591_7492461cfb_b.jpg
#   inflating: sg_dataset/sg_train_images/9725059605_fcb7ebb82d_b.jpg
#   inflating: sg_dataset/sg_train_images/9727996257_dd554865e4_o.jpg
#   inflating: sg_dataset/sg_train_images/9728584093_110c2bea9d_b.jpg
#   inflating: sg_dataset/sg_train_images/9729041998_f0eecf4c48_b.jpg
#   inflating: sg_dataset/sg_train_images/9732014081_9ac07d9688_b.jpg
#   inflating: sg_dataset/sg_train_images/9733935946_f877994033_b.jpg
#   inflating: sg_dataset/sg_train_images/9734831729_d48586e6c7_b.jpg
#   inflating: sg_dataset/sg_train_images/9737277122_d6bc57a14e_b.jpg
#   inflating: sg_dataset/sg_train_images/9738925753_51b7b0a482_b.jpg
#   inflating: sg_dataset/sg_train_images/9743704222_601f5a4b30_b.jpg
#   inflating: sg_dataset/sg_train_images/9752975804_867e778a79_b.jpg
#   inflating: sg_dataset/sg_train_images/9757349321_25782e0e6f_b.jpg
#   inflating: sg_dataset/sg_train_images/9757776836_aacb5138dc_b.jpg
#   inflating: sg_dataset/sg_train_images/9759509291_143489b32a_b.jpg
#   inflating: sg_dataset/sg_train_images/9763456225_334a8cffd5_b.jpg
#   inflating: sg_dataset/sg_train_images/9763666406_2ccafb1192_b.jpg
#   inflating: sg_dataset/sg_train_images/9766932005_d859b2b6da_b.jpg
#   inflating: sg_dataset/sg_train_images/9769797861_69d4203a21_b.jpg
#   inflating: sg_dataset/sg_train_images/977001940_372021dca5_b.jpg
#   inflating: sg_dataset/sg_train_images/9771150101_ddd7581167_b.jpg
#   inflating: sg_dataset/sg_train_images/9771753001_ede067c822_b.jpg
#   inflating: sg_dataset/sg_train_images/9773259026_e3ee29c37e_b.jpg
#   inflating: sg_dataset/sg_train_images/9777495065_95f8e495ca_b.jpg
#   inflating: sg_dataset/sg_train_images/9779255862_a4c3e98f41_b.jpg
#   inflating: sg_dataset/sg_train_images/97897296_c2bca017c7_b.jpg
#   inflating: sg_dataset/sg_train_images/9799188585_7c6ea0cba6_b.jpg
#   inflating: sg_dataset/sg_train_images/9802158925_630fac6493_b.jpg
#   inflating: sg_dataset/sg_train_images/9802830116_a06647c90a_b.jpg
#   inflating: sg_dataset/sg_train_images/9825672843_72849e5bd3_b.jpg
#   inflating: sg_dataset/sg_train_images/9829066303_a49f0f0f2c_b.jpg
#   inflating: sg_dataset/sg_train_images/9835756276_a5fd95029a_b.jpg
#   inflating: sg_dataset/sg_train_images/9847882436_6dfeb09855_b.jpg
#   inflating: sg_dataset/sg_train_images/9848060555_06e6691ee5_b.jpg
#   inflating: sg_dataset/sg_train_images/9850106854_2bd91be0d1_b.jpg
#   inflating: sg_dataset/sg_train_images/9856625974_e40343e7eb_b.jpg
#   inflating: sg_dataset/sg_train_images/9859423596_600a05c506_b.jpg
#   inflating: sg_dataset/sg_train_images/9862618725_b271b9973f_b.jpg
#   inflating: sg_dataset/sg_train_images/9868579766_c160c13d07_b.jpg
#   inflating: sg_dataset/sg_train_images/9868723753_7b34d3cf05_b.jpg
#   inflating: sg_dataset/sg_train_images/9873547783_7b57884d41_b.jpg
#   inflating: sg_dataset/sg_train_images/9873630745_9dcee82f0d_b.jpg
#   inflating: sg_dataset/sg_train_images/9874441925_998fe5d7b3_b.jpg
#   inflating: sg_dataset/sg_train_images/9874798983_f103ac1e0c_b.jpg
#   inflating: sg_dataset/sg_train_images/9875247365_1f49d46b99_b.jpg
#   inflating: sg_dataset/sg_train_images/98752825_6a59fd30ec_b.jpg
#   inflating: sg_dataset/sg_train_images/9883856875_4841d35043_b.jpg
#   inflating: sg_dataset/sg_train_images/9888513253_b6884c5e19_b.jpg
#   inflating: sg_dataset/sg_train_images/9911312755_614d0d6154_b.jpg
#   inflating: sg_dataset/sg_train_images/9920272164_5acece7a05_b.jpg
#   inflating: sg_dataset/sg_train_images/9921297286_02d1347982_b.jpg
#   inflating: sg_dataset/sg_train_images/9921847256_9dafaf7862_b.jpg
#   inflating: sg_dataset/sg_train_images/9928348355_8e9be78597_b.jpg
#   inflating: sg_dataset/sg_train_images/9932805713_438dc590ff_b.jpg
#   inflating: sg_dataset/sg_train_images/9942159516_71df8119d3_b.jpg
#   inflating: sg_dataset/sg_train_images/9944017234_b355a89bc3_b.jpg
#   inflating: sg_dataset/sg_train_images/9951556393_616962e4a4_b.jpg
#   inflating: sg_dataset/sg_train_images/9964390374_e9e6aca637_b.jpg
#   inflating: sg_dataset/sg_train_images/9981721826_063a0589b1_b.jpg
#   inflating: sg_dataset/sg_train_images/9987190063_846930a3f9_o.jpg
#   inflating: sg_dataset/sg_train_images/9993211514_98281b2d04_o.jpg
#   inflating: sg_dataset/sg_train_images/9995825294_cd1c8ac70f_b.jpg

# %%
# !wget http://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Out:
# --2019-12-02 23:36:00--  http://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://nlp.stanford.edu/data/wordvecs/glove.6B.zip [following]
# --2019-12-02 23:36:00--  https://nlp.stanford.edu/data/wordvecs/glove.6B.zip
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.6B.zip [following]
# --2019-12-02 23:36:01--  http://downloads.cs.stanford.edu/nlp/data/wordvecs/glove.6B.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 862182753 (822M) [application/zip]
# Saving to: ‘glove.6B.zip’
#
# glove.6B.zip        100%[===================>] 822.24M  1.97MB/s    in 6m 27s
#
# 2019-12-02 23:42:28 (2.12 MB/s) - ‘glove.6B.zip’ saved [862182753/862182753]

# %%
# !pip install bcolz
# Out:
# Collecting bcolz
#   Downloading https://files.pythonhosted.org/packages/5c/4e/23942de9d5c0fb16f10335fa83e52b431bcb8c0d4a8419c9ac206268c279/bcolz-1.2.1.tar.gz (1.5MB)
#      |████████████████████████████████| 1.5MB 2.8MB/s
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from bcolz) (1.17.4)
# Building wheels for collected packages: bcolz
#   Building wheel for bcolz (setup.py) ... done
#   Created wheel for bcolz: filename=bcolz-1.2.1-cp36-cp36m-linux_x86_64.whl size=2667807 sha256=9a53ff8ad7e49402e8ce82dc7ce873a961cdf46b3828ceb81069f5252b0eb00d
#   Stored in directory: /root/.cache/pip/wheels/9f/78/26/fb8c0acb91a100dc8914bf236c4eaa4b207cb876893c40b745
# Successfully built bcolz
# Installing collected packages: bcolz
# Successfully installed bcolz-1.2.1

# %%
# !unzip /content/glove.6B.zip
# Out:
# Archive:  /content/glove.6B.zip
#   inflating: glove.6B.100d.txt
#   inflating: glove.6B.200d.txt
#   inflating: glove.6B.300d.txt
#   inflating: glove.6B.50d.txt

# %%
import bcolz
import numpy as np
import pickle

words = []
idx = 0
word2idx = {}
vectors = bcolz.carray(np.zeros(1), rootdir=f'6B.50.dat', mode='w')

with open(f'glove.6B.50d.txt', 'rb') as f:
    for l in f:
        line = l.decode().split()
        word = line[0]
        words.append(word)
        word2idx[word] = idx
        idx += 1
        vect = np.array(line[1:]).astype(np.float)
        vectors.append(vect)
    
print(vectors.shape)
vectors = bcolz.carray(vectors[1:].reshape((400001, 50)), rootdir=f'6B.50.dat', mode='w')
vectors.flush()
pickle.dump(words, open(f'6B.50_words.pkl', 'wb'))
pickle.dump(word2idx, open(f'6B.50_idx.pkl', 'wb'))
# Out:
# (20000051,)

# %%
vectors = bcolz.open(f'6B.50.dat')[:]
words = pickle.load(open(f'6B.50_words.pkl', 'rb'))
word2idx = pickle.load(open(f'6B.50_idx.pkl', 'rb'))

glove = {w: vectors[word2idx[w]] for w in words}

# %%
glove["tree"]
# Out:
# array([ 0.62231 ,  1.1986  , -0.014116,  0.20125 ,  0.69419 ,  0.12068 ,
#        -0.90399 , -1.4023  ,  0.43357 , -0.48537 , -0.4645  ,  0.15756 ,
#         0.54261 , -0.32467 , -0.025646,  0.45742 ,  0.16561 ,  0.18819 ,
#         0.062099, -0.86418 , -1.0425  , -0.81157 ,  0.3126  , -0.20279 ,
#         0.55734 , -0.28634 , -0.14874 ,  1.0098  ,  0.25041 , -0.53195 ,
#         2.3793  , -0.76966 , -0.63219 ,  0.3203  ,  0.15072 ,  0.23326 ,
#        -0.26254 , -0.29461 ,  0.7671  , -0.11577 , -0.68129 , -0.65413 ,
#        -0.58914 ,  0.24684 ,  1.5904  ,  0.33025 ,  0.41513 , -1.7468  ,
#         0.82453 , -1.0886  ])

# %%
import imageio
from PIL import Image

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])

# %%
def bbox_mask(img_filename,details):
  img1 = imageio.imread('/content/sg_dataset/sg_train_images/'+img_filename)

  img1 = np.array(img1)
  img1 = img1*0.0
  sub_box=details["bbox1"]
  ob_box=details["bbox2"]
  bboxes = [sub_box[0], sub_box[1], sub_box[2], sub_box[3], ob_box[0], ob_box[1], ob_box[2], ob_box[3]]
  img1[bboxes[0]:bboxes[1], bboxes[2]:bboxes[3]] = 0.5    
  img1[bboxes[4]:bboxes[5], bboxes[6]:bboxes[7]] += 1.0
  img1[bboxes[4]:bboxes[5], bboxes[6]:bboxes[7]] /= 2.0
  img1[bboxes[4]:bboxes[5], bboxes[6]:bboxes[7]] /= 0.75
  img1 = rgb2gray(img1)
  img1 = np.array((img1 * 255).astype(np.uint8))
  img1 = Image.fromarray(img1)
  img1 = img1.resize((100, 100), Image.ANTIALIAS)

  img1 = np.array(img1)
  img1 = img1/255.0
  
  img1 = np.reshape(img1, newshape=[1,img1.shape[0],img1.shape[1],1])

  return img1[0][:,:,0]

# %%
import matplotlib.pyplot as plt

X=[]
y=[]

for i in behind_train_triplets["examples"]:

  trip=[]
  anchor=bbox_mask(i["anchor"],i["anchor_details"])
  positive=bbox_mask(i["positive"],i["positive_details"])
  negative=bbox_mask(i["negative"],i["negative_details"])
  
  

  anchor_sub=i["anchor_details"]["obj1"]
  anchor_ob=i["anchor_details"]["obj2"]

  positive_sub=i["positive_details"]["obj1"]
  positive_ob=i["positive_details"]["obj2"]

  negative_sub=i["negative_details"]["obj1"]
  negative_ob=i["negative_details"]["obj2"]

  anchors=anchor_sub.split(" ")
  if(len(anchors)>1):
    anchor_sub=anchors[0]

  anchors=anchor_ob.split(" ")
  if(len(anchors)>1):
    anchor_ob=anchors[0]

  positives=positive_sub.split(" ")
  if(len(positives)>1):
    positive_sub=positives[0]

  positives=positive_ob.split(" ")
  if(len(positives)>1):
    positive_ob=positives[0]

  negatives=negative_sub.split(" ")
  if(len(negatives)>1):
    negative_sub=negatives[0]

  negatives=negative_ob.split(" ")
  if(len(negatives)>1):
    negative_ob=negatives[0]

  anchor_sub_vec=glove[anchor_sub]
  anchor_ob_vec=glove[anchor_ob]
  positive_sub_vec=glove[positive_sub]
  positive_ob_vec=glove[positive_ob]
  negative_sub_vec=glove[negative_sub]
  negative_ob_vec=glove[negative_ob]

  anchor_flat=anchor.reshape(-1)
  positive_flat=positive.reshape(-1)
  negative_flat=negative.reshape(-1)
  
  anchor_final=np.append(anchor_flat,anchor_sub_vec)
  anchor_final=np.append(anchor_final,anchor_ob_vec)
  
  positive_final=np.append(positive_flat,positive_sub_vec)
  positive_final=np.append(positive_final,positive_ob_vec)

  negative_final=np.append(negative_flat,negative_sub_vec)
  negative_final=np.append(negative_final,negative_ob_vec)


  trip=[anchor_final,positive_final,negative_final]
  X.append(trip)
  y.append(2)
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11796480 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1365333333 bytes but only got 0. Skipping tag 34464
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65536 bytes but only got 3310. Skipping tag 65535
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 603992064 bytes but only got 0. Skipping tag 9
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131074 bytes but only got 3308. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))

# %%
for i in on_train_triplets["examples"]:

  trip=[]
  anchor=bbox_mask(i["anchor"],i["anchor_details"])
  positive=bbox_mask(i["positive"],i["positive_details"])
  negative=bbox_mask(i["negative"],i["negative_details"])
  
  

  anchor_sub=i["anchor_details"]["obj1"]
  anchor_ob=i["anchor_details"]["obj2"]

  positive_sub=i["positive_details"]["obj1"]
  positive_ob=i["positive_details"]["obj2"]

  negative_sub=i["negative_details"]["obj1"]
  negative_ob=i["negative_details"]["obj2"]

  anchors=anchor_sub.split(" ")
  if(len(anchors)>1):
    anchor_sub=anchors[0]

  anchors=anchor_ob.split(" ")
  if(len(anchors)>1):
    anchor_ob=anchors[0]

  positives=positive_sub.split(" ")
  if(len(positives)>1):
    positive_sub=positives[0]

  positives=positive_ob.split(" ")
  if(len(positives)>1):
    positive_ob=positives[0]

  negatives=negative_sub.split(" ")
  if(len(negatives)>1):
    negative_sub=negatives[0]

  negatives=negative_ob.split(" ")
  if(len(negatives)>1):
    negative_ob=negatives[0]

  anchor_sub_vec=glove[anchor_sub]
  anchor_ob_vec=glove[anchor_ob]
  positive_sub_vec=glove[positive_sub]
  positive_ob_vec=glove[positive_ob]
  negative_sub_vec=glove[negative_sub]
  negative_ob_vec=glove[negative_ob]

  anchor_flat=anchor.reshape(-1)
  positive_flat=positive.reshape(-1)
  negative_flat=negative.reshape(-1)
  
  anchor_final=np.append(anchor_flat,anchor_sub_vec)
  anchor_final=np.append(anchor_final,anchor_ob_vec)
  
  positive_final=np.append(positive_flat,positive_sub_vec)
  positive_final=np.append(positive_final,positive_ob_vec)

  negative_final=np.append(negative_flat,negative_sub_vec)
  negative_final=np.append(negative_final,negative_ob_vec)


  trip=[anchor_final,positive_final,negative_final]
  X.append(trip)
  y.append(0)
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 10485760 bytes but only got 0. Skipping tag 55
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6468665344 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 15335424 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 14024704 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 126877996 bytes but only got 0. Skipping tag 4352
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 35651584 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18481152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20054016 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2271805440 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:742: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 4.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3932160 bytes but only got 0. Skipping tag 49
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 12386304 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 12058624 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 126878020 bytes but only got 0. Skipping tag 4352
#   " Skipping tag %s" % (size, len(data), tag))

# %%
for i in under_train_triplets["examples"]:

  trip=[]
  anchor=bbox_mask(i["anchor"],i["anchor_details"])
  positive=bbox_mask(i["positive"],i["positive_details"])
  negative=bbox_mask(i["negative"],i["negative_details"])
  
  

  anchor_sub=i["anchor_details"]["obj1"]
  anchor_ob=i["anchor_details"]["obj2"]

  positive_sub=i["positive_details"]["obj1"]
  positive_ob=i["positive_details"]["obj2"]

  negative_sub=i["negative_details"]["obj1"]
  negative_ob=i["negative_details"]["obj2"]

  anchors=anchor_sub.split(" ")
  if(len(anchors)>1):
    anchor_sub=anchors[0]

  anchors=anchor_ob.split(" ")
  if(len(anchors)>1):
    anchor_ob=anchors[0]

  positives=positive_sub.split(" ")
  if(len(positives)>1):
    positive_sub=positives[0]

  positives=positive_ob.split(" ")
  if(len(positives)>1):
    positive_ob=positives[0]

  negatives=negative_sub.split(" ")
  if(len(negatives)>1):
    negative_sub=negatives[0]

  negatives=negative_ob.split(" ")
  if(len(negatives)>1):
    negative_ob=negatives[0]

  anchor_sub_vec=glove[anchor_sub]
  anchor_ob_vec=glove[anchor_ob]
  positive_sub_vec=glove[positive_sub]
  positive_ob_vec=glove[positive_ob]
  negative_sub_vec=glove[negative_sub]
  negative_ob_vec=glove[negative_ob]

  anchor_flat=anchor.reshape(-1)
  positive_flat=positive.reshape(-1)
  negative_flat=negative.reshape(-1)
  
  anchor_final=np.append(anchor_flat,anchor_sub_vec)
  anchor_final=np.append(anchor_final,anchor_ob_vec)
  
  positive_final=np.append(positive_flat,positive_sub_vec)
  positive_final=np.append(positive_final,positive_ob_vec)

  negative_final=np.append(negative_flat,negative_sub_vec)
  negative_final=np.append(negative_final,negative_ob_vec)


  trip=[anchor_final,positive_final,negative_final]
  X.append(trip)
  y.append(3)
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 4278190080 bytes but only got 0. Skipping tag 256
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2097152 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65536 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2162688 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2686976 bytes but only got 0. Skipping tag 5
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131072 bytes but only got 0. Skipping tag 3
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 56623104 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 368836608 bytes but only got 0. Skipping tag 4
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 729604 bytes but only got 6161. Skipping tag 513
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3846701056 bytes but only got 0. Skipping tag 2
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3300917248 bytes but only got 0. Skipping tag 7
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 262400 bytes but only got 6161. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:742: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 8.
#   warnings.warn(str(msg))

# %%
for i in next_to_train_triplets["examples"]:

  trip=[]
  anchor=bbox_mask(i["anchor"],i["anchor_details"])
  positive=bbox_mask(i["positive"],i["positive_details"])
  negative=bbox_mask(i["negative"],i["negative_details"])
  
  

  anchor_sub=i["anchor_details"]["obj1"]
  anchor_ob=i["anchor_details"]["obj2"]

  positive_sub=i["positive_details"]["obj1"]
  positive_ob=i["positive_details"]["obj2"]

  negative_sub=i["negative_details"]["obj1"]
  negative_ob=i["negative_details"]["obj2"]

  anchors=anchor_sub.split(" ")
  if(len(anchors)>1):
    anchor_sub=anchors[0]

  anchors=anchor_ob.split(" ")
  if(len(anchors)>1):
    anchor_ob=anchors[0]

  positives=positive_sub.split(" ")
  if(len(positives)>1):
    positive_sub=positives[0]

  positives=positive_ob.split(" ")
  if(len(positives)>1):
    positive_ob=positives[0]

  negatives=negative_sub.split(" ")
  if(len(negatives)>1):
    negative_sub=negatives[0]

  negatives=negative_ob.split(" ")
  if(len(negatives)>1):
    negative_ob=negatives[0]

  anchor_sub_vec=glove[anchor_sub]
  anchor_ob_vec=glove[anchor_ob]
  positive_sub_vec=glove[positive_sub]
  positive_ob_vec=glove[positive_ob]
  negative_sub_vec=glove[negative_sub]
  negative_ob_vec=glove[negative_ob]

  anchor_flat=anchor.reshape(-1)
  positive_flat=positive.reshape(-1)
  negative_flat=negative.reshape(-1)
  
  anchor_final=np.append(anchor_flat,anchor_sub_vec)
  anchor_final=np.append(anchor_final,anchor_ob_vec)
  
  positive_final=np.append(positive_flat,positive_sub_vec)
  positive_final=np.append(positive_final,positive_ob_vec)

  negative_final=np.append(negative_flat,negative_sub_vec)
  negative_final=np.append(negative_final,negative_ob_vec)


  trip=[anchor_final,positive_final,negative_final]
  X.append(trip)
  y.append(1)
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 11796480 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 1365333333 bytes but only got 0. Skipping tag 34464
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 65536 bytes but only got 3310. Skipping tag 65535
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 603992064 bytes but only got 0. Skipping tag 9
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 131074 bytes but only got 3308. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 3932160 bytes but only got 0. Skipping tag 49
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 6468665344 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 12386304 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 12058624 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 126878020 bytes but only got 0. Skipping tag 4352
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 35651584 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 18481152 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 20054016 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 2271805440 bytes but only got 0. Skipping tag 0
#   " Skipping tag %s" % (size, len(data), tag))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:742: UserWarning: Corrupt EXIF data.  Expecting to read 12 bytes but only got 4.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.6/dist-packages/PIL/TiffImagePlugin.py:725: UserWarning: Possibly corrupt EXIF data.  Expecting to read 12348030976 bytes but only got 0. Skipping tag 278
#   " Skipping tag %s" % (size, len(data), tag))

# %%
X_train=np.asarray(X)
y_train=np.asarray(y)
print(X_train.shape)
print(y_train.shape)
# Out:
# (3248, 3, 10100)
# (3248,)

# %%
import random
p=np.arange(X_train.shape[0])
random.shuffle(p)
X_train_new=X_train[p,:]
y_train_new=y_train[p]

# %%
print(X_train_new.shape)
print(y_train_new.shape)
# Out:
# (3248, 3, 10100)
# (3248,)

# %%
np.save('/content/X_train.npy',X_train_new)
np.save('/content/y_train.npy',y_train_new)

# %%
np.save('/content/drive/My Drive/X_train_with_glove.npy',X_train_new)
np.save('/content/drive/My Drive/y_train_with_glove.npy',y_train_new)
